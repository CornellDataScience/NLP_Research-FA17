# %%
# %matplotlib inline
import pandas as pd
import json
from pprint import pprint
from random import sample
from nltk.tokenize import word_tokenize
import nltk
import seaborn as sns
import numpy as np

# %%
def json_df(datapass):
    '''
    Load the json file and parse the file to pandas dataframe format
    
    Input:
        datapass(str) : directory to the json file
    Output:
        df(dataframe) : pandas dataframe object
    '''
    
    data = [] 
    with open(datapass, 'r', encoding='utf-8') as data_file: 
        for f in data_file:
            data.append(json.loads(f))
    df = pd.DataFrame(data)
    return df

#business and review json files --> dataframes

DATAPASS1 = 'C:\\Users\\cdchang\\Downloads\\yelp_dataset\\dataset\\business.json'
business = json_df(DATAPASS1)
DATAPASS2 = 'C:\\Users\\cdchang\\Downloads\\yelp_dataset\\dataset\\review.json'
reviews = json_df(DATAPASS2)

# %%
'''
TODO: come up with function that outputs the unique business ids from different
      categories found in the business json

first thing just look at business
which subcategories have more reviews
(cross reference)

group by subcategories
list of business IDs
cross reference, with review files
which categories have more data

CATEGORY --> BUSINESS IDS

'''

#business.head(3)

#category_all

#1. create a dictionary with each entry's set of categories
# specifically, create the appropriate keys and values 
#2.

# %%
category_list = business[business.columns[3]]
category_all = category_list
#category head count
def category_head_count(cat):
    '''
    generate head counts of all different categories, then
    return total number of occurences of that specific category
    
    Input:
        cat(str) : category phrase
    Output:
        by_category[cat] : frequency of category
    '''
    
    by_category = {}
    for word_string in category_all:
        for indiv in word_string:
            if indiv not in by_category:
                by_category[indiv] = 1
            else:
                by_category[indiv]+=1
    
    return by_category[cat]

#example
#category_head_count('Shopping')

def category_count(df):
    '''
    return a dictionary that maps category to the unique business count
    Input:
        df(dataframe) : business dataframe with the column name 'categories'
    Output:
        categories(list) : sorted list of tuple ('category', business)
    '''
    categories = {}
    for C in df.categories:
        for c in C:
            if c in categories:
                categories[c] += 1
            else:
                categories[c] = 1
                
    categories = sorted(categories.items(), key=lambda x: x[1], reverse = True)
    return categories

category_count(business)
# Out:
# [('Restaurants', 51613),
#  ('Shopping', 24595),
#  ('Food', 23014),
#  ('Beauty & Spas', 15139),
#  ('Home Services', 13202),
#  ('Health & Medical', 12033),
#  ('Nightlife', 11364),
#  ('Bars', 9868),
#  ('Automotive', 9476),
#  ('Local Services', 9343),
#  ('Event Planning & Services', 8038),
#  ('Active Life', 7427),
#  ('Fashion', 6299),
#  ('Sandwiches', 5864),
#  ('Fast Food', 5792),
#  ('American (Traditional)', 5737),
#  ('Pizza', 5652),
#  ('Coffee & Tea', 5565),
#  ('Hair Salons', 5395),
#  ('Hotels & Travel', 5188),
#  ('Arts & Entertainment', 5054),
#  ('Home & Garden', 4584),
#  ('Auto Repair', 4480),
#  ('Italian', 4411),
#  ('Burgers', 4236),
#  ('Doctors', 4124),
#  ('Breakfast & Brunch', 4103),
#  ('Mexican', 3913),
#  ('Nail Salons', 3884),
#  ('Professional Services', 3865),
#  ('American (New)', 3802),
#  ('Chinese', 3775),
#  ('Real Estate', 3729),
#  ('Specialty Food', 3620),
#  ('Fitness & Instruction', 3615),
#  ('Pets', 3153),
#  ('Grocery', 3044),
#  ('Bakeries', 3014),
#  ('Cafes', 2812),
#  ('Hair Removal', 2704),
#  ('Dentists', 2683),
#  ('Hotels', 2548),
#  ('Desserts', 2419),
#  ('Skin Care', 2398),
#  ("Women's Clothing", 2355),
#  ('Education', 2209),
#  ('Japanese', 2186),
#  ('Ice Cream & Frozen Yogurt', 2159),
#  ('Pet Services', 2113),
#  ('Day Spas', 2084),
#  ('Massage', 2068),
#  ('General Dentistry', 2056),
#  ('Financial Services', 2053),
#  ('Pubs', 2024),
#  ('Chicken Wings', 2019),
#  ('Seafood', 1981),
#  ('Contractors', 1939),
#  ('Salad', 1850),
#  ('Gyms', 1836),
#  ('Sushi Bars', 1833),
#  ('Sports Bars', 1781),
#  ('Apartments', 1776),
#  ('Caterers', 1714),
#  ('Flowers & Gifts', 1699),
#  ('Sporting Goods', 1662),
#  ('Beer', 1657),
#  ('Wine & Spirits', 1657),
#  ('Cosmetics & Beauty Supply', 1651),
#  ('Oil Change Stations', 1635),
#  ('Tires', 1633),
#  ('Accessories', 1600),
#  ('Venues & Event Spaces', 1565),
#  ('Delis', 1564),
#  ('Hair Stylists', 1557),
#  ('Asian Fusion', 1554),
#  ('Barbers', 1543),
#  ('Waxing', 1483),
#  ('Mediterranean', 1482),
#  ('Auto Parts & Supplies', 1479),
#  ('Trainers', 1478),
#  ('Car Dealers', 1455),
#  ('Furniture Stores', 1455),
#  ('Home Decor', 1452),
#  ('Cosmetic Dentists', 1437),
#  ('Drugstores', 1415),
#  ('Barbeque', 1413),
#  ('Department Stores', 1395),
#  ("Men's Clothing", 1388),
#  ('Canadian (New)', 1357),
#  ('Lounges', 1346),
#  ('Arts & Crafts', 1336),
#  ('Jewelry', 1323),
#  ('Convenience Stores', 1322),
#  ('Steakhouses', 1311),
#  ('Thai', 1291),
#  ('Indian', 1289),
#  ('Juice Bars & Smoothies', 1203),
#  ('Eyelash Service', 1185),
#  ('Massage Therapy', 1163),
#  ('Medical Centers', 1163),
#  ('Books', 1161),
#  ('Mags', 1161),
#  ('Music & Video', 1161),
#  ('Pet Groomers', 1158),
#  ('Diners', 1132),
#  ('Heating & Air Conditioning/HVAC', 1127),
#  ('Electronics', 1126),
#  ('Public Services & Government', 1106),
#  ('Dry Cleaning & Laundry', 1094),
#  ('Laundry Services', 1072),
#  ('Shoe Stores', 1065),
#  ('Gas Stations', 1059),
#  ('Specialty Schools', 1046),
#  ('IT Services & Computer Repair', 1034),
#  ('Veterinarians', 1027),
#  ('Chiropractors', 1022),
#  ('Party & Event Planning', 989),
#  ('Real Estate Services', 984),
#  ('Wine Bars', 978),
#  ('Optometrists', 973),
#  ('Middle Eastern', 958),
#  ('Mobile Phones', 957),
#  ('Pet Boarding/Pet Sitting', 956),
#  ('Greek', 956),
#  ('French', 952),
#  ('Banks & Credit Unions', 950),
#  ('Plumbing', 930),
#  ('Vietnamese', 928),
#  ('Yoga', 926),
#  ('Pet Stores', 913),
#  ('Cocktail Bars', 894),
#  ('Vegetarian', 889),
#  ('Makeup Artists', 889),
#  ('Performing Arts', 878),
#  ('Home Cleaning', 874),
#  ('Music Venues', 873),
#  ('Eyewear & Opticians', 862),
#  ('Medical Spas', 853),
#  ('Body Shops', 844),
#  ('Car Wash', 835),
#  ('Transportation', 831),
#  ('Printing Services', 826),
#  ('Local Flavor', 816),
#  ('Parks', 801),
#  ('Florists', 790),
#  ('Dance Clubs', 785),
#  ('Hair Extensions', 781),
#  ('Ethnic Food', 761),
#  ('Movers', 757),
#  ('Landscaping', 752),
#  ('Real Estate Agents', 751),
#  ('Buffets', 743),
#  ('Tanning', 729),
#  ('Discount Store', 728),
#  ('Auto Detailing', 727),
#  ('Photographers', 725),
#  ('Tobacco Shops', 705),
#  ('Physical Therapy', 704),
#  ('Car Rental', 703),
#  ('Korean', 697),
#  ('Self Storage', 688),
#  ('Food Delivery Services', 684),
#  ('Property Management', 681),
#  ('Carpet Cleaning', 675),
#  ('Sewing & Alterations', 674),
#  ('Orthodontists', 672),
#  ('Tattoo', 665),
#  ('Lawyers', 656),
#  ('Tex-Mex', 644),
#  ('Soup', 641),
#  ('Food Trucks', 626),
#  ('Auto Glass Services', 621),
#  ('Hobby Shops', 615),
#  ('Appliances & Repair', 608),
#  ('Shipping Centers', 607),
#  ('Hot Dogs', 606),
#  ('Gluten-Free', 606),
#  ('Donuts', 605),
#  ('Appliances', 602),
#  ('Kitchen & Bath', 602),
#  ('Used', 597),
#  ('Vintage & Consignment', 597),
#  ('Insurance', 592),
#  ('Art Galleries', 588),
#  ('Comfort Food', 584),
#  ('Hardware Stores', 584),
#  ('Building Supplies', 578),
#  ('Vegan', 573),
#  ('Sports Wear', 571),
#  ('Wedding Planning', 570),
#  ('Flooring', 570),
#  ('Health Markets', 567),
#  ('Mattresses', 565),
#  ('Family Practice', 564),
#  ('Gift Shops', 561),
#  ('Thrift Stores', 546),
#  ('Bagels', 535),
#  ('Dive Bars', 534),
#  ("Men's Hair Salons", 529),
#  ('Tours', 521),
#  ('Oral Surgeons', 521),
#  ('Weight Loss Centers', 519),
#  ('Caribbean', 509),
#  ('German', 504),
#  ('Gastropubs', 504),
#  ('Acupuncture', 503),
#  ('Mobile Phone Repair', 503),
#  ('Child Care & Day Care', 500),
#  ('Bookstores', 492),
#  ('Vape Shops', 490),
#  ('Bikes', 485),
#  ('Nurseries & Gardening', 473),
#  ('Latin American', 469),
#  ('Blow Dry/Out Services', 464),
#  ('Toy Stores', 462),
#  ('Preschools', 462),
#  ('Bridal', 460),
#  ('Electronics Repair', 456),
#  ('Pest Control', 455),
#  ('Pet Training', 450),
#  ('Antiques', 450),
#  ('Interior Design', 441),
#  ('Photography Stores & Services', 437),
#  ('Golf', 437),
#  ('Pool Cleaners', 436),
#  ('Computers', 427),
#  ('Shopping Centers', 426),
#  ('Mortgage Brokers', 426),
#  ('Martial Arts', 426),
#  ('Pediatric Dentists', 423),
#  ('Breweries', 422),
#  ('Laser Hair Removal', 420),
#  ('Cinema', 415),
#  ('Towing', 409),
#  ('Festivals', 407),
#  ('Meat Shops', 406),
#  ('Sports Clubs', 400),
#  ('Session Photography', 398),
#  ('Halal', 394),
#  ('Event Photography', 393),
#  ('Swimming Pools', 390),
#  ('Religious Organizations', 390),
#  ('Southern', 387),
#  ('Imported Food', 380),
#  ("Children's Clothing", 380),
#  ('Nutritionists', 379),
#  ('Handyman', 376),
#  ('Graphic Design', 371),
#  ('Tapas/Small Plates', 368),
#  ('Community Service/Non-Profit', 366),
#  ('Chocolatiers & Shops', 365),
#  ('Tea Rooms', 362),
#  ('Casinos', 361),
#  ('Notaries', 360),
#  ('Pool & Hot Tub Service', 354),
#  ('Electricians', 352),
#  ('Pakistani', 349),
#  ('Painters', 346),
#  ('Obstetricians & Gynecologists', 346),
#  ('Elementary Schools', 346),
#  ('Urgent Care', 343),
#  ('Transmission Repair', 340),
#  ('Internet Service Providers', 335),
#  ('Hospitals', 333),
#  ('Diagnostic Services', 332),
#  ('Reflexology', 330),
#  ('Office Cleaning', 329),
#  ('Naturopathic/Holistic', 326),
#  ('Fruits & Veggies', 319),
#  ('British', 318),
#  ('Museums', 317),
#  ('Piercing', 313),
#  ('Farmers Market', 311),
#  ('Auto Customization', 310),
#  ('Tapas Bars', 310),
#  ('Windshield Installation & Repair', 309),
#  ('Travel Services', 307),
#  ('Office Equipment', 304),
#  ('Cosmetic Surgeons', 302),
#  ('Churches', 301),
#  ('Endodontists', 300),
#  ('Damage Restoration', 300),
#  ('Fish & Chips', 300),
#  ('Cards & Stationery', 299),
#  ('Marketing', 298),
#  ('Party Supplies', 295),
#  ('Keys & Locksmiths', 293),
#  ('Hot Tub & Pool', 293),
#  ('Arcades', 293),
#  ('Limos', 292),
#  ('Dance Studios', 290),
#  ('Adult Entertainment', 288),
#  ('Musical Instruments & Teachers', 288),
#  ('Amusement Parks', 286),
#  ('Karaoke', 283),
#  ('Carpeting', 283),
#  ('Personal Injury Law', 283),
#  ('Pilates', 282),
#  ('Permanent Makeup', 282),
#  ('Periodontists', 282),
#  ('Watches', 281),
#  ('Spray Tanning', 279),
#  ('Boot Camps', 279),
#  ('Candy Stores', 278),
#  ('Ophthalmologists', 276),
#  ('Outdoor Gear', 274),
#  ('Security Systems', 273),
#  ('Music & DVDs', 272),
#  ('Windows Installation', 271),
#  ('Art Supplies', 265),
#  ('Shades & Blinds', 264),
#  ('Pediatricians', 264),
#  ('Airport Shuttles', 264),
#  ('Street Vendors', 264),
#  ('Sports Medicine', 263),
#  ('Noodles', 263),
#  ('Internal Medicine', 261),
#  ('Baby Gear & Furniture', 259),
#  ('Tax Services', 258),
#  ('Outlet Stores', 256),
#  ('Smog Check Stations', 255),
#  ('Food Stands', 255),
#  ('Tree Services', 255),
#  ('Web Design', 254),
#  ('Couriers & Delivery Services', 253),
#  ('Libraries', 251),
#  ('Landmarks & Historical Buildings', 250),
#  ('Hawaiian', 249),
#  ('Auto Insurance', 247),
#  ('Videos & Video Game Rental', 246),
#  ('Wholesale Stores', 244),
#  ('Motorcycle Dealers', 243),
#  ('Recreation Centers', 242),
#  ('Beer Bar', 241),
#  ('Garage Door Services', 239),
#  ('Hookah Bars', 238),
#  ('Post Offices', 236),
#  ('Dermatologists', 236),
#  ('Soul Food', 235),
#  ('Water Heater Installation/Repair', 235),
#  ('Bubble Tea', 235),
#  ('Motorcycle Repair', 230),
#  ('Cajun/Creole', 230),
#  ('Shoe Repair', 230),
#  ('Dim Sum', 230),
#  ('Counseling & Mental Health', 229),
#  ('Colleges & Universities', 229),
#  ('Roofing', 225),
#  ('Mass Media', 225),
#  ('Playgrounds', 224),
#  ('Dog Walkers', 222),
#  ('Portuguese', 221),
#  ('Bike Repair/Maintenance', 220),
#  ('Home & Rental Insurance', 220),
#  ('Lighting Fixtures & Equipment', 218),
#  ('Taxis', 218),
#  ('Guns & Ammo', 218),
#  ('Window Washing', 217),
#  ('Modern European', 216),
#  ('Accountants', 214),
#  ('Eyebrow Services', 213),
#  ('Cupcakes', 212),
#  ('Creperies', 210),
#  ('Formal Wear', 209),
#  ('Home Inspectors', 209),
#  ('Criminal Defense Law', 208),
#  ('Bike Rentals', 207),
#  ('Lingerie', 205),
#  ('Masonry/Concrete', 204),
#  ('Chicken Shop', 204),
#  ('Wheel & Rim Repair', 201),
#  ('Signmaking', 201),
#  ('Dry Cleaning', 200),
#  ('Swabian', 196),
#  ('Leather Goods', 196),
#  ('Kids Activities', 196),
#  ('Bowling', 195),
#  ('Gardeners', 195),
#  ('Jewelry Repair', 192),
#  ('Landscape Architects', 192),
#  ('Orthopedists', 191),
#  ('Divorce & Family Law', 191),
#  ('Organic Stores', 189),
#  ('Truck Rental', 189),
#  ('Shaved Ice', 188),
#  ('Vitamins & Supplements', 187),
#  ('Hiking', 186),
#  ('Financial Advising', 186),
#  ('Spanish', 186),
#  ('Public Transportation', 185),
#  ('Car Stereo Installation', 184),
#  ('Door Sales/Installation', 184),
#  ('Seafood Markets', 183),
#  ('Threading Services', 181),
#  ('Life Coach', 180),
#  ('Butcher', 180),
#  ('Pool Halls', 179),
#  ('Party Equipment Rentals', 179),
#  ('Filipino', 176),
#  ('Comic Books', 175),
#  ('Irish', 174),
#  ('Cheesesteaks', 173),
#  ('Cabinetry', 173),
#  ('Advertising', 172),
#  ('Interval Training Gyms', 172),
#  ('Turkish', 170),
#  ('Cheese Shops', 170),
#  ('Fabric Stores', 168),
#  ('Gay Bars', 167),
#  ('Irrigation', 166),
#  ('Lebanese', 164),
#  ('Reiki', 163),
#  ('Pawn Shops', 163),
#  ('Taiwanese', 161),
#  ('Boxing', 160),
#  ('Resorts', 159),
#  ('Junk Removal & Hauling', 158),
#  ('Furniture Reupholstery', 158),
#  ('Rehabilitation Center', 157),
#  ('Diagnostic Imaging', 157),
#  ('Educational Services', 157),
#  ('Home Window Tinting', 156),
#  ('Bed & Breakfast', 156),
#  ('Watch Repair', 156),
#  ('Air Duct Cleaning', 155),
#  ('Persian/Iranian', 151),
#  ('Middle Schools & High Schools', 150),
#  ('Glass & Mirrors', 149),
#  ('Television Service Providers', 148),
#  ('Laser Eye Surgery/Lasik', 148),
#  ('Delicatessen', 146),
#  ('Dance Schools', 146),
#  ('DJs', 145),
#  ('DUI Law', 144),
#  ('Summer Camps', 143),
#  ('Video/Film Production', 142),
#  ('Ramen', 142),
#  ('Brasseries', 142),
#  ('Amateur Sports Teams', 142),
#  ('Patisserie/Cake Shop', 141),
#  ('Wineries', 140),
#  ('Stadiums & Arenas', 140),
#  ('Do-It-Yourself Food', 140),
#  ('Legal Services', 140),
#  ('Mobile Phone Accessories', 139),
#  ('Art Classes', 139),
#  ('Home Health Care', 137),
#  ('Social Clubs', 133),
#  ('Bistros', 133),
#  ('Traditional Chinese Medicine', 133),
#  ('Commercial Real Estate', 132),
#  ('Pressure Washers', 132),
#  ('Used Car Dealers', 131),
#  ('Comedy Clubs', 131),
#  ('Screen Printing/T-Shirt Printing', 131),
#  ('Airports', 130),
#  ('Internet Cafes', 130),
#  ('Employment Agencies', 129),
#  ('Barre Classes', 128),
#  ('Laboratory Testing', 128),
#  ('African', 128),
#  ('Vinyl Records', 127),
#  ('Food Court', 126),
#  ('Water Purification Services', 126),
#  ('Podiatrists', 125),
#  ('Home Theatre Installation', 124),
#  ('Adult Education', 124),
#  ('Gun/Rifle Ranges', 123),
#  ('Bankruptcy Law', 122),
#  ('Auto Loan Providers', 122),
#  ('Plus Size Fashion', 121),
#  ('Cosmetology Schools', 121),
#  ('Tiling', 121),
#  ('Carpet Installation', 120),
#  ('Art Schools', 120),
#  ('Funeral Services & Cemeteries', 118),
#  ('Home Organization', 118),
#  ('General Litigation', 118),
#  ('Parking', 117),
#  ('Dog Parks', 117),
#  ('Escape Games', 117),
#  ('Medical Supplies', 116),
#  ('Framing', 115),
#  ('Boating', 115),
#  ('Jazz & Blues', 115),
#  ('Solar Installation', 114),
#  ('Musical Instrument Services', 114),
#  ('Knitting Supplies', 113),
#  ('Telecommunications', 113),
#  ('Check Cashing/Pay-day Loans', 112),
#  ('Drywall Installation & Repair', 112),
#  ('Data Recovery', 112),
#  ('Adult', 111),
#  ('Personal Shopping', 110),
#  ('Gold Buyers', 109),
#  ('International', 109),
#  ('Cannabis Clinics', 109),
#  ('Estate Planning Law', 108),
#  ('Videographers', 107),
#  ('Poutineries', 106),
#  ('Kosher', 106),
#  ('Animal Shelters', 106),
#  ('Refinishing Services', 105),
#  ('Print Media', 104),
#  ('Tacos', 103),
#  ('Departments of Motor Vehicles', 102),
#  ('Tattoo Removal', 101),
#  ('Life Insurance', 101),
#  ('Airlines', 100),
#  ('Fences & Gates', 99),
#  ('Party Bus Rentals', 99),
#  ('Pet Adoption', 98),
#  ('Falafel', 98),
#  ('Nail Technicians', 98),
#  ('Costumes', 97),
#  ('RV Repair', 96),
#  ('Yelp Events', 96),
#  ('Car Window Tinting', 96),
#  ('Gelato', 96),
#  ('Wigs', 95),
#  ('RV Dealers', 95),
#  ('Laundromat', 94),
#  ('Photo Booth Rentals', 94),
#  ('Psychics & Astrologers', 94),
#  ('Screen Printing', 92),
#  ('Peruvian', 92),
#  ('Custom Cakes', 89),
#  ('Driving Schools', 89),
#  ('Real Estate Law', 89),
#  ('Afghan', 88),
#  ('Recycling Center', 87),
#  ('Herbs & Spices', 86),
#  ('Beer Garden', 85),
#  ('Coffee Roasteries', 85),
#  ('Gymnastics', 84),
#  ('Private Tutors', 84),
#  ('Video Game Stores', 83),
#  ('Rugs', 83),
#  ('Ear Nose & Throat', 83),
#  ('Pain Management', 83),
#  ('Swimwear', 83),
#  ('Investing', 82),
#  ('Tanning Beds', 81),
#  ('Retirement Homes', 81),
#  ('Home Automation', 80),
#  ('Business Law', 80),
#  ('Customized Merchandise', 79),
#  ('Radiologists', 79),
#  ('Vehicle Wraps', 79),
#  ('Pan Asian', 78),
#  ('Brazilian', 78),
#  ('Surgeons', 78),
#  ('Pharmacy', 76),
#  ('Hot Pot', 76),
#  ('Cardiologists', 75),
#  ('Paint & Sip', 75),
#  ('Szechuan', 75),
#  ('Horseback Riding', 75),
#  ('Scottish', 75),
#  ('Irish Pub', 75),
#  ('Waffles', 74),
#  ('Radio Stations', 74),
#  ('Cooking Schools', 74),
#  ('Tennis', 74),
#  ('Ethiopian', 73),
#  ('Shutters', 73),
#  ('Mini Golf', 73),
#  ('Embroidery & Crochet', 73),
#  ('Beer Gardens', 72),
#  ('Tutoring Centers', 72),
#  ('International Grocery', 72),
#  ('Skating Rinks', 72),
#  ('University Housing', 71),
#  ('Gutter Services', 71),
#  ('Uniforms', 71),
#  ('Roadside Assistance', 70),
#  ('Wholesalers', 69),
#  ('Battery Stores', 69),
#  ('Cantonese', 69),
#  ('Head Shops', 68),
#  ('Pretzels', 68),
#  ('Cycling Classes', 67),
#  ('Wraps', 66),
#  ('Paint Stores', 66),
#  ('Vacation Rentals', 66),
#  ('Cuban', 66),
#  ('Motorcycle Gear', 66),
#  ('Payroll Services', 66),
#  ('Vocational & Technical School', 66),
#  ('Kebab', 66),
#  ('Allergists', 65),
#  ('Leisure Centers', 65),
#  ('Poke', 65),
#  ('Neurologist', 65),
#  ('Swimming Lessons/Schools', 65),
#  ('Personal Chefs', 65),
#  ('Hostels', 64),
#  ('Mountain Biking', 64),
#  ('Polish', 64),
#  ('Metal Fabricators', 63),
#  ('Special Education', 63),
#  ('Business Consulting', 62),
#  ('Packing Services', 62),
#  ('Propane', 62),
#  ('Train Stations', 61),
#  ('Country Clubs', 61),
#  ('Malaysian', 61),
#  ('Cardio Classes', 61),
#  ('Wedding Chapels', 61),
#  ('Utilities', 60),
#  ('Fitness/Exercise Equipment', 60),
#  ('Moroccan', 60),
#  ('Countertop Installation', 60),
#  ('Live/Raw Food', 60),
#  ('Walk-in Clinics', 59),
#  ('Occupational Therapy', 59),
#  ('Teeth Whitening', 59),
#  ('Midwives', 58),
#  ('Security Services', 58),
#  ('Golf Equipment', 58),
#  ('Salvadoran', 58),
#  ('Registration Services', 58),
#  ('Campgrounds', 58),
#  ('RV Rental', 58),
#  ('Ticket Sales', 58),
#  ('Boat Repair', 57),
#  ('Septic Services', 57),
#  ('Soccer', 57),
#  ('Test Preparation', 57),
#  ('Luggage', 56),
#  ('Guitar Stores', 56),
#  ('Arabian', 55),
#  ('Shared Office Spaces', 55),
#  ('Pasta Shops', 54),
#  ('Challenge Courses', 54),
#  ('Professional Sports Teams', 54),
#  ('Career Counseling', 53),
#  ('Russian', 53),
#  ('Rafting/Kayaking', 52),
#  ('Maternity Wear', 52),
#  ('Immigration Law', 52),
#  ('Mortgage Lenders', 52),
#  ('Home Staging', 51),
#  ('Cannabis Dispensaries', 51),
#  ('Outdoor Furniture Stores', 50),
#  ('Furniture Repair', 49),
#  ('Psychiatrists', 49),
#  ('Souvenir Shops', 49),
#  ('Packing Supplies', 49),
#  ('Trampoline Parks', 49),
#  ('Zoos', 49),
#  ('Fertility', 49),
#  ('Bespoke Clothing', 48),
#  ('Beaches', 48),
#  ('Meditation Centers', 48),
#  ('Henna Artists', 48),
#  ('Mailbox Centers', 48),
#  ('RV Parks', 47),
#  ('Himalayan/Nepalese', 47),
#  ('Fireplace Services', 47),
#  ('Newspapers & Magazines', 46),
#  ('Climbing', 46),
#  ('Boat Charters', 46),
#  ('Hats', 45),
#  ('Flea Markets', 45),
#  ('Guest Houses', 45),
#  ('Emergency Pet Hospital', 45),
#  ('Personal Assistants', 45),
#  ('Hypnosis/Hypnotherapy', 44),
#  ('Belgian', 44),
#  ('Mongolian', 44),
#  ('Patio Coverings', 44),
#  ('Fondue', 44),
#  ('Cooking Classes', 43),
#  ('Audiologist', 43),
#  ('Insulation Installation', 42),
#  ('Urologists', 42),
#  ('Diving', 41),
#  ('Macarons', 41),
#  ('Aquariums', 41),
#  ('Firearm Training', 40),
#  ('Orthotics', 40),
#  ('ATV Rentals/Tours', 40),
#  ('Lakes', 40),
#  ('Emergency Rooms', 40),
#  ('Auction Houses', 40),
#  ('Artificial Turf', 39),
#  ('Popcorn Shops', 39),
#  ('Vehicle Shipping', 39),
#  ('TV Mounting', 39),
#  ('Officiants', 39),
#  ('Laser Tag', 39),
#  ('Title Loans', 39),
#  ('Endocrinologists', 38),
#  ('Carpenters', 38),
#  ('Botanical Gardens', 38),
#  ('Aquarium Services', 38),
#  ('Argentine', 38),
#  ('Hospice', 38),
#  ('Hearing Aid Providers', 38),
#  ('Smokehouse', 37),
#  ('Colombian', 37),
#  ('Recording & Rehearsal Studios', 37),
#  ('Bus Tours', 37),
#  ('Acai Bowls', 37),
#  ('Buses', 37),
#  ('Wills', 37),
#  ('Trusts', 37),
#  ('& Probates', 37),
#  ('Musicians', 36),
#  ('Employment Law', 36),
#  ('Tabletop Games', 36),
#  ('Car Buyers', 36),
#  ('Karate', 36),
#  ('Airport Lounges', 35),
#  ('Osteopathic Physicians', 35),
#  ('Golf Lessons', 35),
#  ('Police Departments', 35),
#  ('Appraisal Services', 34),
#  ('Auto Upholstery', 34),
#  ('Race Tracks', 34),
#  ('Boat Dealers', 34),
#  ('Scuba Diving', 34),
#  ('Magicians', 34),
#  ('Water Stores', 34),
#  ('Gastroenterologist', 34),
#  ('Cafeteria', 33),
#  ('CPR Classes', 33),
#  ('Vinyl Siding', 33),
#  ('Speech Therapists', 33),
#  ('Taekwondo', 33),
#  ('Cambodian', 33),
#  ('Hair Loss Centers', 33),
#  ('Paddleboarding', 32),
#  ('Furniture Assembly', 32),
#  ('Water Delivery', 32),
#  ('Sugaring', 32),
#  ('Blood & Plasma Donation Centers', 32),
#  ('Whiskey Bars', 32),
#  ('Go Karts', 31),
#  ('Pool & Billiards', 31),
#  ('Assisted Living Facilities', 31),
#  ('Talent Agencies', 31),
#  ('Archery', 31),
#  ('Kickboxing', 31),
#  ('Decks & Railing', 30),
#  ('Opera & Ballet', 30),
#  ('Skate Parks', 30),
#  ('Bookkeepers', 30),
#  ('Walking Tours', 30),
#  ('Flight Instruction', 30),
#  ('Oncologist', 30),
#  ('Bartenders', 30),
#  ('Beverage Store', 30),
#  ('Paintball', 29),
#  ('Montessori Schools', 29),
#  ('Face Painting', 29),
#  ('Races & Competitions', 29),
#  ('Wine Tasting Room', 29),
#  ('Coffee & Tea Supplies', 29),
#  ('Television Stations', 29),
#  ('Community Centers', 28),
#  ('Ethnic Grocery', 28),
#  ('Food Tours', 28),
#  ('Cultural Center', 28),
#  ('Saunas', 28),
#  ('Skate Shops', 28),
#  ('Piano Services', 28),
#  ('Lactation Services', 27),
#  ('Colonics', 27),
#  ('Tai Chi', 27),
#  ('Hungarian', 27),
#  ('Historical Tours', 27),
#  ('Christmas Trees', 27),
#  ('Trophy Shops', 27),
#  ('Basque', 27),
#  ('Snow Removal', 27),
#  ('Trailer Repair', 26),
#  ('Distilleries', 26),
#  ('Motorcycle Rental', 26),
#  ('Home Network Installation', 26),
#  ('Real Estate Photography', 26),
#  ('Medical Transportation', 26),
#  ('Spiritual Shop', 26),
#  ('Doulas', 26),
#  ('Team Building Activities', 25),
#  ('Sleep Specialists', 25),
#  ('Condominiums', 25),
#  ('Fishing', 25),
#  ('Engraving', 25),
#  ('Commercial Truck Repair', 24),
#  ('Private Investigation', 24),
#  ('Wine Tours', 24),
#  ('Cabaret', 24),
#  ('Massage Schools', 24),
#  ('Mobile Dent Repair', 24),
#  ('Sri Lankan', 24),
#  ('Farms', 24),
#  ('Champagne Bars', 24),
#  ('Bail Bondsmen', 23),
#  ('Brewing Supplies', 23),
#  ('Dental Hygienists', 23),
#  ('Chimney Sweeps', 23),
#  ('Health Retreats', 23),
#  ('Hunting & Fishing Supplies', 23),
#  ('Teppanyaki', 23),
#  ('Piano Bars', 23),
#  ('Traffic Ticketing Law', 23),
#  ('Language Schools', 23),
#  ('First Aid Classes', 22),
#  ('Indonesian', 22),
#  ('Day Camps', 22),
#  ('Cryotherapy', 22),
#  ('Awnings', 22),
#  ('Psychologists', 22),
#  ('New Mexican Cuisine', 22),
#  ('Stucco Services', 22),
#  ('Rock Climbing', 21),
#  ('Architects', 21),
#  ('Art Museums', 21),
#  ('Software Development', 21),
#  ('Courthouses', 21),
#  ('Float Spa', 20),
#  ('Haunted Houses', 20),
#  ('Jet Skis', 20),
#  ('Paint-Your-Own Pottery', 20),
#  ('Donairs', 20),
#  ('Fire Protection Services', 20),
#  ('Batting Cages', 20),
#  ('Estate Liquidation', 20),
#  ('Hakka', 20),
#  ('Disc Golf', 20),
#  ('Venezuelan', 20),
#  ('Shredding Services', 20),
#  ('Vacation Rental Agents', 20),
#  ('Hydro-jetting', 19),
#  ('Currency Exchange', 19),
#  ('Knife Sharpening', 19),
#  ('Public Relations', 19),
#  ('Horse Boarding', 19),
#  ('Debt Relief Services', 19),
#  ('Singaporean', 19),
#  ('Skilled Nursing', 19),
#  ('IV Hydration', 19),
#  ('Brazilian Jiu-jitsu', 19),
#  ('Puerto Rican', 19),
#  ('Installment Loans', 19),
#  ('High Fidelity Audio Equipment', 19),
#  ('Powder Coating', 18),
#  ('Home Energy Auditors', 18),
#  ('Pet Breeders', 18),
#  ('Speakeasies', 18),
#  ('Nanny Services', 18),
#  ('Wildlife Control', 18),
#  ('Local Fish Stores', 18),
#  ('Pet Photography', 18),
#  ('Waterproofing', 18),
#  ('Editorial Services', 18),
#  ('Bangladeshi', 18),
#  ('Country Dance Halls', 17),
#  ('Anesthesiologists', 17),
#  ('Coffeeshops', 17),
#  ('Translation Services', 17),
#  ('Used Bookstore', 17),
#  ('Health Insurance Offices', 17),
#  ('Ukrainian', 17),
#  ('Tax Law', 17),
#  ('Restaurant Supplies', 16),
#  ('Town Car Service', 16),
#  ('Travel Agents', 16),
#  ('Workers Compensation Law', 16),
#  ('Prosthodontists', 16),
#  ('South African', 16),
#  ('Muay Thai', 16),
#  ('Bingo Halls', 16),
#  ('Golf Equipment Shops', 16),
#  ('Pop-up Shops', 16),
#  ('Ski & Snowboard Shops', 15),
#  ('Farming Equipment', 15),
#  ('Livestock Feed & Supply', 15),
#  ('Demolition Services', 15),
#  ('Religious Schools', 15),
#  ('Prosthetics', 15),
#  ('Business Financing', 15),
#  ('Firewood', 15),
#  ('Party Characters', 15),
#  ('Clothing Rental', 15),
#  ('Commercial Truck Dealers', 15),
#  ('Spine Surgeons', 15),
#  ('Holiday Decorations', 15),
#  ('Hydrotherapy', 15),
#  ('Shoe Shine', 14),
#  ('Pet Transportation', 14),
#  ('Dominican', 14),
#  ('Pet Cremation Services', 14),
#  ('Fingerprinting', 14),
#  ('Pole Dancing Classes', 14),
#  ('Hot Air Balloons', 14),
#  ('Furniture Rental', 14),
#  ('Ethic Grocery', 14),
#  ('CSA', 14),
#  ('Laotian', 14),
#  ('Matchmakers', 13),
#  ('Bavarian', 13),
#  ('Oxygen Bars', 13),
#  ('Curry Sausage', 13),
#  ('Personal Care Services', 13),
#  ('Tiki Bars', 13),
#  ('Auto Security', 13),
#  ('Ski Resorts', 13),
#  ('Mortuary Services', 13),
#  ('Music Production Services', 13),
#  ('Pulmonologist', 13),
#  ('Scandinavian', 13),
#  ('Trailer Dealers', 13),
#  ('Farm Equipment Repair', 13),
#  ('Serbo Croatian', 12),
#  ('Prenatal/Perinatal Care', 12),
#  ('Austrian', 12),
#  ('Medical Cannabis Referrals', 12),
#  ('Grilling Equipment', 12),
#  ('Clock Repair', 12),
#  ('Boudoir Photography', 12),
#  ('Egyptian', 12),
#  ('Valet Services', 12),
#  ('House Sitters', 12),
#  ('Machine & Tool Rental', 12),
#  ('Baseball Fields', 11),
#  ('Basketball Courts', 11),
#  ('Motorsport Vehicle Dealers', 11),
#  ('Tasting Classes', 11),
#  ('Nurse Practitioner', 11),
#  ('Buddhist Temples', 11),
#  ('Mobility Equipment Sales & Services', 11),
#  ('Rheumatologists', 11),
#  ('Clowns', 11),
#  ('Acne Treatment', 11),
#  ('Passport & Visa Services', 11),
#  ('Rolfing', 11),
#  ('Traffic Schools', 11),
#  ('Empanadas', 11),
#  ('Racing Experience', 11),
#  ('Car Share Services', 11),
#  ('Synagogues', 11),
#  ('Burmese', 11),
#  ('Childbirth Education', 11),
#  ('College Counseling', 10),
#  ('Homeowner Association', 10),
#  ('Placenta Encapsulations', 10),
#  ('Cremation Services', 10),
#  ('Bartending Schools', 10),
#  ('Castles', 10),
#  ('Christmas Markets', 10),
#  ('Drive-In Theater', 10),
#  ('Chinese Martial Arts', 10),
#  ('Olive Oil', 10),
#  ('Marinas', 10),
#  ('Lice Services', 10),
#  ('Spin Classes', 10),
#  ('Parenting Classes', 9),
#  ('Horse Equipment Shops', 9),
#  ('Skydiving', 9),
#  ('Perfume', 9),
#  ('Piano Stores', 9),
#  ('Motorsport Vehicle Repairs', 9),
#  ('Dinner Theater', 9),
#  ('Australian', 9),
#  ('Airsoft', 9),
#  ('Haitian', 9),
#  ('Caricatures', 9),
#  ('Aerial Fitness', 9),
#  ('Dumpster Rental', 9),
#  ('Badminton', 9),
#  ('Aerial Tours', 9),
#  ('Car Inspectors', 9),
#  ('Solar Panel Cleaning', 9),
#  ('Shanghainese', 8),
#  ('Mediators', 8),
#  ('Airport Terminals', 8),
#  ('Environmental Testing', 8),
#  ('Roof Inspectors', 8),
#  ('Hydroponics', 8),
#  ('Dance Wear', 8),
#  ('Golf Cart Rentals', 8),
#  ('Water Parks', 8),
#  ('Bar Crawl', 8),
#  ('Squash', 8),
#  ('Circuit Training Gyms', 8),
#  ('Observatories', 8),
#  ('Environmental Abatement', 8),
#  ('Bird Shops', 8),
#  ('Holistic Animal Care', 7),
#  ('Holiday Decorating Services', 7),
#  ('Vascular Medicine', 7),
#  ('Process Servers', 7),
#  ('Armenian', 7),
#  ('Boat Tours', 7),
#  ('Product Design', 7),
#  ('Party Bike Rentals', 7),
#  ('Ayurveda', 7),
#  ...]

# %%
from collections import defaultdict
def business_id_retrieval(cat):
    '''
    
    Input:
        cat(str) : category 
    Output:
       id_list[cat] : business ids (values) of a particular category (key)
    '''
    id_list = dict()
    idx = 0
    for word_string in category_all:
        for indiv in word_string:
            if indiv not in id_list:
                id_list[indiv] = []
            else:
                id_list[indiv].append(business.business_id[idx])
        idx+=1

    return id_list[cat]

#business_id_retrieval("Shopping")

def business_id_retrieval(cat, business):

    '''
    Input:
        cat(str) : category
        business(dataframe) : the business data
    Output:
        id_list(set) : business ids of a particular category
    '''

    id_list = set()
    idx = 0
    for row in business.values: #for every row
        categories = row[3]     #third entry in each row
        if cat in categories:
            id_list.add(row[2])
    return id_list

#business_id_retrieval("Shopping")
business_id_retrieval("Shopping", business)
# Out:
# {'BzGtPzyD1dzn1e2MQVcMzw',
#  'kXU9vc5R1hZW6W10sRxNjg',
#  'EgryhB7DPw3hHXx5Sifm9A',
#  'ZFnaRxkNAAb_CxOZgnz9BA',
#  'ajnY7XSEBLwtUPrrmQOsag',
#  'ye_70WYrVEN7BfZr3hZ8LA',
#  'c9j-ppVLItgtAlPRRRwxJw',
#  'j6RfW-vH8yp701qKvAVaWA',
#  '_fSHHJkjkpFUZd6IsoC-RA',
#  'D0gKNbcK7wxi35v6tvn1qA',
#  'gflx3mAzi4iG20NOUz19eA',
#  'DiZ2rabncBaCrNG3OB-CBA',
#  '93Z8Af87euo4OtMi825_ZA',
#  'ImD9jhFSAXWlTr8EHCwv9Q',
#  '0cjSdDntuRKGqt5ek_QzCA',
#  'f07-YU_I3DCMgtQqJqo4fg',
#  'i0RYOFGt9-jP9Rmoxvp88g',
#  'aEsgRpuTtFhmnMbPRj6Qvg',
#  '5UOfIIoAyWLqzWR0EhOTGg',
#  '9y7EXkufgR8wkI3f0FEBeQ',
#  'rsrAF29oNtBqM7A0XnR4ag',
#  'm73UAPgnQ_f8QSgwk0NG2A',
#  '_y-5z5oOzqcoy3FjjHFWUg',
#  'frPrxrfbTEscTCKVZzPRQw',
#  'vMlXebPewC6hAK8k85llBA',
#  'lStkivpZKaVTibt1EWPFZQ',
#  'BnYadh_BSwBV4z-acodXNQ',
#  'j-sioijZPDgVT8RUtkCI5Q',
#  'PqdmH8amagBvBKUF1SC2JA',
#  '5VEYRYVIU2Bm-U1AqJNiQw',
#  'oXD2W3ZtaivlQyLCvDDvzQ',
#  'HqZSJgkqCs6oJO5hrE1LhQ',
#  '2YyPbMR1Ef26N974cEAUNg',
#  'HIt0BE1N56uN5H67J9w8gA',
#  'le6qyZAW2DCyp0sgbaP2qg',
#  'VfYjrvBqXDttErkUi_6_7w',
#  'Y350WjZ01_N8R7GW11bO_w',
#  'v_O_y6rEUlsTajiTolDgDw',
#  'WTx3doIwTx040yDMsrYwYw',
#  'dwLfu8PGUIqGB-svwXAnJw',
#  'yPXc62YLqG93TmBHY0bhYg',
#  'DEp6Gxku4Gz22jcjCgl-LA',
#  'VR0D2Le_OGEJTnYHCSrFnA',
#  '5WoHYemsAjuK85AOcGwEJg',
#  'Cf9DM_cxB0mAsmX3w8NNgw',
#  'ghVFRHRk_ERo0f7cJCcEBw',
#  'kvtAMdXpAcxCLZFg-DlqJg',
#  'vihHVj2IE54fzYxmhzr70Q',
#  '8Q0WD7Uo3uxKuhNFTdgIzA',
#  '0HG9ioe3luHKuFlAGK9Ozg',
#  'JK5d7YGj7zovNb654XEcaQ',
#  'Vusxa8XxCc7gOV3TlVwwRg',
#  'WSoQHh4Dc4y8jaufPl3ZQw',
#  'FoU5sNX7QPKahchxd0gHkQ',
#  'oF-CrytdPldmLKLh6oKoww',
#  'fnD9TymuJHE_xcKcNjFDfw',
#  'Eu4JwXc2logjyOAoaqzYAg',
#  'BcaA9jvHhuPoTJXz0RMZ6A',
#  'aG8GWT6G90A4aqlJcRLNfQ',
#  'AsWkpQ0g8-U1WM9qBv5TOQ',
#  'dDUwSI1py94WMo0uTW2SLg',
#  'nYzdu6yYv_sg_j8nE67PSw',
#  'vw3uhpv1YyO5bjv3YWMgzg',
#  '0qmt3BsHn56qly5HSD7FEw',
#  'sH9WsMj8sNTTSAUWv4UEEg',
#  'P2AzIIA9_4W7CFFXfqjwhw',
#  'q_qDA1mGb1LgmX823XvCDQ',
#  'W9YR0qsYX6IMswKiWnT_JQ',
#  'dNRAVgeEyFXx6ZCraVD8-g',
#  'KOfyWvemZm2iVLq5Y7v_Wg',
#  'eEuYMudJcvgW0kXBRawqTg',
#  'wNlTKt_r4EGrPTvoH3zb1g',
#  'i57pboNTvHTaIyKOx2p-9Q',
#  'LgSmlKSc8zMlcXuwSHVYkg',
#  'XvrweCwu7SurjLMw-ZoIOg',
#  'HQ-JuSquwiI1RrZPCjyUIQ',
#  'zohR5_VezlcJvhMdp0NXEg',
#  'oHEmEgOGSIrFV8TnoYSq3A',
#  'dJsUjChHpP0ma7zWBE109w',
#  'lkJYQIiVkykNjagPY48YqA',
#  'h0TYeluEJJuO4UFg5C9w0Q',
#  '5jBbLDUVZZWHZlVH-nPc8A',
#  '1-7_qijotsTGyHh2XyejuA',
#  '3Cnonn4ook40H8Pu1NeDMw',
#  '3SLMbM0m_9zQObNZ9gPoXg',
#  '_q79zpnAAwDLdIfenDuqYQ',
#  'QEiSyJxVkSV5gVggwzlbxw',
#  'uj9jdgTjIMaMnaOfy1tVjw',
#  '1teFm9hpEt8lKV6OY7P9bg',
#  'd5t8aHwVXMJ5I_hcwem6qQ',
#  'QV-01NzTQk3LfI2tPk21zw',
#  'v9p3_505kir_PjnmV6a2TQ',
#  'OS3Y96FhiHwRLyiRfppaDw',
#  'h4YD1rFPRqOBNx3pq3aQlQ',
#  'UbpeWBXXE9qMkPd0stAscA',
#  'QLe7HPMV2IB2UZAl1AzcDg',
#  'dWVdagUK60qFoTTmOz696w',
#  'nf4kkyHbw_FnaErNZDs1Pw',
#  'JHPq9KvMuJaC7CPATSYeew',
#  'UQ31DsMtbeRqHWtMnmaI7w',
#  'Tg2zZ_cBsGxjHXCAGQvT0g',
#  'yVHm6K6waWeNROOD53AmPg',
#  'li0zwq50mul49BPqK7wo-w',
#  'iK7VC9GOkXkDzEuScNxZNg',
#  'ugysvQDxFj5AZZYzVxgPDQ',
#  'ATsw5yU--5HU-KDdlfgH3A',
#  'wVQcg0maCR1kNGL_Lz8fFw',
#  '1uP_zBaJlawlIGQ8kaLraA',
#  'AlqXtLlzldYiFb2ofgXe4A',
#  'negmHffTWsRXc6oSf_upsA',
#  '-JlPpUujIsfALWB4hT-4_Q',
#  'NNqZ17O-ixEpo1Vyx-OIZg',
#  'MhQ7U1z-Ey8I8n80Osc75g',
#  'Z2lUlZvJZsAturQjLLjVsg',
#  '_XTOxMZ30pHy4V4q7aol1Q',
#  'cPxG4mVFdmPfX7hUT5M-5A',
#  'DFR-v3bainumQZA3hiNfsA',
#  'GLB5X9kjmS1SA1UXzNSxQQ',
#  'Ram0p8Sdrwh7HV5hjDEdkA',
#  '-boDId8zTvrgPwdlYYpWzg',
#  'THQcdDr-9faO7nMUlfxLzw',
#  'TGTQOGAgQ1O3sfTjZ0zuOg',
#  'Ffaz5R_AMddqHsVqLRZicA',
#  'SQv2RHAH1-MGXV_IWpQFzQ',
#  'p-V1yg3K0krGnukd302kHw',
#  'TwDhEG7qMJHKtJLkbHR3PA',
#  'S9V5s2ka3dXgOpoc_yjzbQ',
#  'Q70TX19skg8v9OL6VIdF3A',
#  'Cd_JVOq_cBueqB9q3X0rkQ',
#  'QXA3A98cch3Kf0jJT3QDDQ',
#  'uiEKYwYiUT2CsIT5g5yuDQ',
#  'EYwgMTQ5AMFkJpfmrZG_PQ',
#  'YCuzXyxmPBNeeEr7lkWPmA',
#  '5xI4eMdOc5_GT5jk6V0TNA',
#  'WU2VLi7Qm7Weq0uWjOZPGg',
#  'ItQMDgwz39QVvyWJFywPrA',
#  'fXALOm7UCLvg7vuS11sy0g',
#  'B4pcyJs_0U_YHgr1WQu1Dw',
#  'LFhkMq9DCSGpYI5Cdlpyiw',
#  'BlL19xTC9hVbqKSMZQp2-w',
#  '4yDzhf-Ap7RSr9slOYZgrA',
#  '4exHE7rhmc2SZorJlsvvxw',
#  'ISTtJWIKQ4ONxnbEzcx5cg',
#  'emJungvsYbiex7iIBYeCdQ',
#  'UBEUfivF3-Y1mw0YLKx86g',
#  'b0bzVtF_EJmVUioNwSigfw',
#  'IyISPnt5tyC7ZnaG0XyAjw',
#  'oGLcax_n3h1ZIDVHuC8HKA',
#  'hYQOT0fwr-saCjbaD9kvAA',
#  '7nwdI1IGQicFAkYljdfjjg',
#  '7q7RWPwljKtmX-fbSinuHw',
#  '-k3KkKg2dPUpOK3QgNnprA',
#  'WVF4jqrtDJ49sCgOo_RK0w',
#  'tnOTjnZ0UZ_ZvBRMaaQbUw',
#  'jYQhAv5UjMvqFiYIpaFyvA',
#  '5KGrQ8fNo6Q0SS4T2bgZGg',
#  'CDRRGEktCvI8mYTIKLPiMQ',
#  'v52PcQkmE6-ocx5Co4EJ-A',
#  'Ws0_gbdmdFYaXHnhe-vXqQ',
#  'wVuIwsYDsCE9eWe5HDBGeg',
#  'uV9yyMyAHKLg2mxUHcHjfg',
#  'SLGqasr7KxiJWpWepzjLRA',
#  'u1r_9dDn4JxiK2yNmn4XIQ',
#  '3STgMi8D-cx8LJv3Wr6_OQ',
#  '3KNC2yixPC68n3MyEivl3A',
#  'RC0MyBO6xX9_xeN2a_fN2Q',
#  '4E0cn2L4uQitNciAScE1wg',
#  'IdZYzuUDVYkmqUkV6tgqXA',
#  '3Io2EgTy7R_Qg9LxJZP8MA',
#  'vBKASqi_a0A07WTTnMkGlw',
#  'qvMUdKuXu-9TjNXYeEDJTw',
#  'OOnIQMkjg1VpAcPRFLnM0g',
#  'VqB4aRlWvk1ZAXEpqRxRYQ',
#  '0GnX8C16wjr-m6tHGwB5tQ',
#  'jWj48I59PBLs1w9eEyGYrQ',
#  'dHTRPKBakY9e3yPK1OReag',
#  'YNmIDsu0Xuyxw7MMKczePw',
#  'GMsG__dBcMKyQGah9xTvmA',
#  'yhhADeS0eu4dws_6rz36TA',
#  'tVe-dxm2sKcrRNEvnHxgoA',
#  '3WAqlDxxhR8JjEOmU2E0Rg',
#  'wyeB7gu2Pw6ZT7Oz627dSg',
#  'oHwHEnks9WNP6innmm9-Qw',
#  '0El9Pih1Dd1bcdxxakpKYA',
#  'w6QrDDXc5z-_GSxa6egU5g',
#  'f9Y4OhUzvXI6e18fGNKIjQ',
#  'af4CYXhh5Bz6eDxit7gAcA',
#  'gDaSuImqd1V1Pk7IOULBZA',
#  'rn--KkYlY0p8C_tZkCFeFg',
#  'zTEAgV-YSyg7Mek2S20Xcw',
#  'PJ_osNYvfjjqERSmiOD-jw',
#  'cJD2TIkd1Cn2JNs0MNpxwA',
#  'b3RzoJRUnQyJGcMNtXK5rA',
#  'FO07MQ2jUn0NArSxWmxrSQ',
#  'vHhoGKA9KssWAma6MTzQZA',
#  '8QZTISWvsNQzI6P7loxRIA',
#  'D4KYo0Idk4Djg7weQn6aXQ',
#  'DlYwY1E1nSBsbuT-IPzx1w',
#  'hV58TCLS0DqbrNXS3-jKBw',
#  'BF676wK7kAWFyFbh4fLpHg',
#  'c4QTwhK5pjd6qyb_UJ8v7Q',
#  '7UAZHmdlbj5mqU_n1DK8ww',
#  'HS74qlJTYFUug6vC-L8HZg',
#  'Kyq49Dzmrl3kenz-p9k8BQ',
#  'IBJ0ICw6ffdnEIBhpKHO2g',
#  'G4R_qBZbBel3T-f5V7XYKw',
#  'yrzvJNRMnB7WfT8hdAhrKQ',
#  'WCU8xnlwoS5Zh62FHrlrvw',
#  'Auy2w1PNycTomFXMwdC6Zw',
#  'zSxV5z7YXWtMoZQyDskCKQ',
#  'nbmD3ua5pVPyBpWYtrwIBA',
#  'ELbc-hl-ACPwGTNMtm7izw',
#  'hdgYnadxg0GANhWOJabr2g',
#  'KN5W6mXc6Xzv7UZGNnZGRQ',
#  'O9WOMBkzYOEN-wBX6-Mfhg',
#  'x_j0pXOevL_v8egsEDcBBw',
#  'SZJriXdVqncvjNaO8Bv9yg',
#  'bdFUA6DGPmiQqtK6iuAEzw',
#  '783qMhPSIRhMvM5O8WXiww',
#  'MLlWRHzNnQ4XKzELqgLeqA',
#  'z87fV9z_MM6XPiO-Kob57g',
#  'XrFF2f26Lc9uNu0gVc7PvQ',
#  'oRKxu7iFAb-OScRiVSzgOQ',
#  'JOGS2iI3L9mRgwiGzgSBxg',
#  '_80vznYut7O0Vq6F5-95Zw',
#  'qT1OowsSbjUcT_57p1Lrsw',
#  'yi0itQ1CpjC3KskLzTmqPw',
#  't0aja59cII8eEVmC_x4sBw',
#  'PUpUNzYPo5oNP7LyI7BT6Q',
#  '49uxSUtYJQNbXnw6EilHAw',
#  'epyhvtf5JH5sAJggINVglg',
#  'WLpt7FwpKD-DDktLgwBbfQ',
#  '3C_AT9Phdl1m857tW7Q-eA',
#  'q0rM1zkC3C6XoNY0UOy_qQ',
#  'OWI5DFD5v7PtoAJncfeT5w',
#  '67D8fbXNN0MULZGmpzU48w',
#  'z4LyMZIluAjlXBLcg76eRw',
#  'F-tLdSvPfzSC16HHba8_CQ',
#  'ERfIGfcA8-QJjETjKTJ5Xg',
#  'mWIPwl-Ub6RMr2tfiYQONw',
#  'k21n-ho6z6VKCCsOON2mdQ',
#  'tsSZDrHEjomSvkVk40sGZw',
#  'WQdBScO6HhkJXwdnmRRClg',
#  'gNeiLxkopO1FgN4mjDESsA',
#  'q44LjJZnNYOKhwSpdLGpdw',
#  'sqnr6XgcNNk26GHPq1_IpA',
#  '6XVfWi6GU_VCaYDTs5Vw7g',
#  '5uN6wSFQG3WD7MFeaZymiw',
#  'A9bxTXfUm2r3-3HvykIjiQ',
#  'Ex1s434OH86X7Ue8z6Zblg',
#  'STmbtI-ivQnh0KM_2sptcg',
#  'EwBome2EKTcALO4hqu7oMw',
#  'CHzLDG3T58GOQI2TuvXDQg',
#  'FFhVWAEz3nUy_4JEssvlvQ',
#  'ieEHX6LBG-y3k36x-uA0Vw',
#  'qosZtMMGbjeuZ0DQ1qPc3g',
#  'QS-8Jo9pvtLGGofEseX1Cg',
#  '1CSMpBHr3mYd9XEOldM2yw',
#  'vFiVoPTOhFoiktwS2k7ZzQ',
#  'z6SfkCI5JI7zbY7fuOPQOA',
#  'yWxL9xODQvI1EnPMPGp1pw',
#  'EjgPwxGTEM4H06cqOTuphw',
#  '09pjh8dL9AavSLHkdKT4VQ',
#  'NkBho7U7t2-opanALkoCZA',
#  'ObNwrIOcHTCfh2CX6kQLlA',
#  'Xr5ECBBmj4-EuvOSprCySA',
#  'Az0v-7xgM8XcT0BOLyN3Lg',
#  '2Hc_JqGw01a2PlOlXtniaQ',
#  'BWhspaDdGQwZAkXieytvUQ',
#  'B5OWN-uGRNh2dvtSl42Uiw',
#  'o_ptsyF-ffg_I6x9ddiyqw',
#  '8ib-z_n6POLhroKos3RgLw',
#  'LZr69iki37amNk7KRhr_7g',
#  'gbrP-MYK6Bhv5Oo8QPTCXA',
#  'WBIV2m_aLLB4TbThvVr2Ew',
#  'QIvONrq74qFuIGH5SrZwcg',
#  'cEYA1VHP65yW_8IKMvkv3Q',
#  'iYaVR-libOJL1Twgl6zgYw',
#  'wW2gksIa03G2bGCh6vbMNA',
#  'ofmRryAjoYgyd5jfhVSPFg',
#  '0lFslC_punpFW38fdiBK8g',
#  'ZehpqfpyGzJMT1PJIWsT3w',
#  'Q2gNDnvI2aDurFT2iMfJwQ',
#  'ElzlhCMpv21O8W0BZNe-jw',
#  'qbtrctwkovS8uNXWc-_CkA',
#  '9o6KmFAH41ESD5JqWQp_fQ',
#  'OzbrkTpd3uU144Obwq8wYw',
#  'npmFDfZKWEXq7EyWcQ3ujQ',
#  '_1INWCewsouOSkwNCPo0-Q',
#  'PhZBbi6479FE_heACm0fNQ',
#  '7iV5frbYn3FSRGxqmCnC_Q',
#  'wQNm_35uvGOiiVKO42IX-A',
#  'Ouxhu_-wZcfVawDQ1FJs-Q',
#  'y14n-2Yh78TXFWOf2X-pmw',
#  'eAFHgthVWTOenjmTc5guog',
#  'nrs_ZzWC3379Ga_rHlSgEw',
#  'uMbXJFvJRUon8NlUc8b5Dw',
#  'EeJGZILBRpuWcPII_G5JBQ',
#  '6Ef2Ovnj-DLsXzUQyG2b7w',
#  'pWKoNuhpl87AozKnfLQbhg',
#  'RqmA6Dsya4FmksZpWMYrcQ',
#  '8hUjpJt7qJAcQQZnhZglhw',
#  'KBwm6RN-A9yLEjr-lbYXmQ',
#  'whR3bOtam3uW4l6Q3YezXg',
#  'NWY04fnx_9bySycRrF4APQ',
#  'Y_nb799g_-23JLARNBOgZw',
#  'aG6vwbA3qx2Te5KNFiK_zA',
#  'bvXikt2p11iWuOOJ3H_gzA',
#  'T_U6jmjNWJ-DgqE3LDJ3vA',
#  'Hg4Ih249vvT4y7Mbr4EiSA',
#  'Kq1KvJ9vtyeo9iQfaSdZOQ',
#  'MEcl1Rv8UQ3Er77M2BNi2A',
#  'U3J-_BUCNDgcmNBLm3-R5w',
#  '9iAVEdj9_ESR0AhS-7ZuWA',
#  'Bbl8O6JQKXbtoKslcQw_EA',
#  '2D3IgP6Bu28GxoNXBrChaQ',
#  'lVomzvlzgjsBa8Szcrt93A',
#  '7Lk5dZzfysJdHhUrPRuO1Q',
#  'xqTLe5cTwXkDMa9oI2qZhA',
#  'im2VbhBjiTWwxaizyvQubg',
#  'T96ueOXgTy_pl4IGw447Vw',
#  '0e_T-v1IygJWAqulJX7EeA',
#  '6Uf3RcK16NZeTxYTHXAD-Q',
#  'YV-mbGBCOOiw4ftlUcNm3Q',
#  'zskAX7jD0IaRb3I_gFCWOw',
#  'mfvcmwmtC7ZgzrdwSaL4kg',
#  'GDk6SJN5XckC1_nc777-Bw',
#  'RhcYsu8Mo1qx2nZ4jAtCXw',
#  'Jts5vT3G8D-6Vg-ssa9kWg',
#  'dRDd9zMMH96jl_BlE2-jkA',
#  '8xI4hJ3nS4avEoo_l62dkw',
#  'qrPbFiwRT5F_4HLHZVL26Q',
#  '3j_8fQ3G3V3LEJuq8O-RTQ',
#  'ZUfmPlxbHrQVxTkkog3QqA',
#  'TbJ4nTCOT5NhAsl65qWSZg',
#  'tIBNatp7EWKDaqLokN8xmQ',
#  'Ic-thFnyyqI6Nj7hxRuM4g',
#  'm9YuuCsXmRjeOjFPSzrSyw',
#  'Jr0-xuQYSKzfjn6B0O-3hg',
#  'y85ZeeSpmvbYn67zTwXAdA',
#  'TT9u-iVu9mtq7tdCTJWwnw',
#  'Y2IB6wFs_sYYou_rOwC1xQ',
#  'TKeiQuLVDLheXy9RSlKMYA',
#  'SRUJMPwIcvh70wO-1VUmJg',
#  '2fcQCO92NKOHNJwfjALAmg',
#  'szRcXD8bV6m74PLDaIgBAg',
#  'gQpxdmYRKZYAZZa-cR1nsg',
#  'NlihCGMn9fEVYstZNd6yLQ',
#  'Ld62zKGvw2j_N7j6gphJqQ',
#  'E6QR3kLQKsHO2xS6tCiYGw',
#  'HDiuyuc77aRnw9UpF8gm0Q',
#  'kskhznHQtJFmNw6BQD2KMQ',
#  'wdnon4fvX67mmFZRaL_msA',
#  'LnNe9JYkjp-HWdTctLxb0g',
#  'AYC9OcLWJNPz9fWIsGF9cA',
#  '_CnQ9snaSz8IIuKpNGj7KA',
#  'iO7YqYFrZDg-yPg9v-Omxg',
#  'GRtBvvrAGjWtty-hHQ0VqQ',
#  'snRS_TWdgykx0VWg417YVg',
#  'JrEEn-KvqX_B2KM3FF1FDg',
#  '7azfFXMtlWioQHXDdc6fiA',
#  'LpqQap8AZsEOc5bXwQlKdw',
#  'n0_3bK9oEpkokUafWfoD9Q',
#  'bitQ2L6iywDAMsPnk1NM-w',
#  'v0p0GjlFm2Q_PsrlBxC6PA',
#  'hCxSE_etPwuVP0ca0bcixQ',
#  'c5hy97P0kmHxncwWwoTK3g',
#  'MlIQON0U5-nFSiVez2mT4Q',
#  'G7sCRZ1R5pQuMd6NsvrqKA',
#  'V9_yatKS0WQl_bvLg7u-2g',
#  'K3IlRTSfbLl0Czwn2LkMSQ',
#  'pPMmfL3oeMp9rfXmZrpfBA',
#  'ec9aKZryi2yx5o3aN1jNeQ',
#  'hn2bFpwAKg-EE4jnYWEE6g',
#  'MYRlurnsNgZC9pZRft3-9Q',
#  'EtdQDs03fAxM5LCKNEn8Lg',
#  'qD2RxaIOEwaOVxNj6aYqbA',
#  'RshUhfxSaLJN421LlEgwnA',
#  'hJ88unGZxRYN85XQ0qAS4g',
#  'Hcr9mXHyytOzt_LulhNvkA',
#  'd8SWJ-jqoQosKans_IF_9A',
#  'gyFFy7UjeDAxMJXzSJ0KCg',
#  'lV_ws-TSIuvQ2NysULXj8g',
#  'UM2Yya0Fycjb5WUcajuJDw',
#  'w7q6WWyHWaect7BPXgSAmg',
#  'cFXbnUGRNYI4gVR2WIBHlQ',
#  'qTBLBmgkYGItc8oxTsGJ_A',
#  'zdGO-0i4eKugu1vfoL1hPQ',
#  '1MYERX0eFE6BtmsScOPMvA',
#  'Zpm5UEc-sJ7mkS-yLC7uzw',
#  'olXovJuBNPKhxsBd0DHEog',
#  '4FV0pTmEMLRlIt3v5dJ8GA',
#  'IuNrwXlBmPUlJaU5MdEj-A',
#  'UmXeaoQgfQVOXesvt-8fuw',
#  '2kDqdCwG3w12rKkTfeNZ8w',
#  'xwdvkz6Mlu_KlXzBEblsew',
#  'jurypgAYmCOd69X69nTbDA',
#  'rZPIj01V8PjhtnpJoDTP4Q',
#  '_J-jaBz8p-ukliSdSTf76g',
#  '3hVNB2plzW9c3UY3f7ur8Q',
#  'I9Y-4JhE4thXVfw--3Azhg',
#  'jO2gfBUSu4k6uJAF7voqxA',
#  'TzSWrznzIe0MKsZjakFE9Q',
#  'NYq6uICDibj7lFCmSUpjBQ',
#  'cU9xu6narmRUoawgJNGtQQ',
#  'O22t8G6O15TPI_zD7lGMGA',
#  '3dJuMXIoToDdq_n499sXpg',
#  '7X8x4N3oETeOM2WaG1aIsw',
#  '8BAWsFbOxEtTl8Vj54S9wA',
#  'jlHd9i_YsKDl9ogp_SORvQ',
#  '8f0zn63DcudBwS89lE7gcw',
#  'JS6oyJp-wBIrXDNAKA5PlQ',
#  'YJaUuKGG-eaUBsd7i7zK_Q',
#  'Gcv-LPo8EF_9EDBWt_4XmA',
#  'eNTQnauT_i5a0NvlQRVBlw',
#  'cC_yy42_rw_0V8ZfWg11Iw',
#  '7s5396BO2bYxyjMwZeWwmw',
#  'gP8s25-O3HlMEcbA7ZYW3g',
#  '3wLdY8qi1e11xMoZKZ6jyw',
#  'szhQMdcVJHT4SX-vGlzSEw',
#  '5LKYxGD0Mb4JgrfXiUVsqw',
#  '7n_w4VOgy85GqbCCq64Ykw',
#  'GyDqfXn2NGh9ylltUvkLag',
#  'fn53cY_qMDPnYvdV48_hVg',
#  'n0PBF76ogdgFCsJoOW_L1w',
#  'aBV0ayr7xjjpn61tSe5-eA',
#  'sVWC2YgCuZsoiVqvqbQHYQ',
#  'LNmIrETEDjjigUQvhjppFg',
#  'Lo8tZxknWNuItM_a6eBiqg',
#  'rGIot51q5jJH7HtB48lZzA',
#  '7YrQH44kboYLS8f8ROz37w',
#  'EXMLrw5uxng5z-T9Z2X8oA',
#  'EK3bsv-dFDGnmdQLoHl3SA',
#  'Usiq70a6m4NO0OM35lG3cg',
#  'J3pGDad4vj7sAAOI81e_zA',
#  'SrTFTykMa0oMUWbJxXGcQw',
#  'Cnj3Gk01u1LfqdU7SxKnnA',
#  'GuSk6ON_K8A-nMNZ_zmknA',
#  'fni1W-Bc9CipWeOmzRg88Q',
#  '1b-vQVOAcACAlRwEnYACDg',
#  'ZPVM-AgASSPY7OAuzezJ4w',
#  'FvSDzOzyHP8M-zLDv93b1g',
#  'X4_mDMmLUm7AiVYn0qR9PA',
#  '62ogX9hFQpFM0G6EzhdZLg',
#  '6OjPcTK1pN7QlLFOI9VQYQ',
#  'jlYHQMP6hfLIkhKEjzlGOg',
#  'xMMPZ6zhH9h3lozwA8vtAg',
#  'AFO7kGp_LXdVI44jeYyIuw',
#  'uQK3FTgQ9LVT5hsel8Jjrg',
#  '2Z59ijv2HXwcYfAQSbAvyQ',
#  '6uLERmN7HzXEU7HkXqzrSQ',
#  'La-deTxOcGc6YDrm3xBNcQ',
#  'gp7g3l3pQqGL1O0VQEYPIg',
#  'Uv8VBHwAaCQnx741ftpMFQ',
#  'myFKAkdX6sJdD0n3SYgW3A',
#  'LEVEQg9r-Ykp_4seShi5cA',
#  'afKlYlV0-l2PBUDYz5Fysw',
#  'z1WYPE8veVRKnV7411XtDQ',
#  'FMKTxPgCXrn6ZBVLtQLTRA',
#  'Ceeild05Ksq0bTWbbRtsGw',
#  'U_HTXIeGY64vdmuaTWfevg',
#  'jGW9GXw28Ey1PMbznHZFJQ',
#  'qVPlT07EJCA8gSdrCTk40w',
#  'LWMKFanOJ_eaZUv1x9i2TA',
#  'hbculKnTyMBeMQgN3j0QxQ',
#  'DBO0rgw9k2tlL8dtaaf2Og',
#  'ZpRt2D9ME9NpLuYU9tmOtQ',
#  'QXpSFLpP7B9st9zzpZmrRw',
#  'yy35cFhSe9n-RSyO820FNg',
#  'zU4O55DsAkjGlskgwL-0iw',
#  'CA4qhLICQWX0H_bf9iGw0Q',
#  'Yo65nhylmE1LhNSlbDP-9Q',
#  'vfgRn_5VXelOjKcIDZcT9g',
#  'I4tHOlZt_lhvKmuvZwtMmA',
#  'YpQYRMJS2_pDi6--5fqnng',
#  '3vMRXMtzmSzaAc7d6iPwDg',
#  'o0l3wOkWAilMXejWhtB-Rg',
#  'a5CEZ-ab2tYrfRuiPGOncw',
#  'izd105KSPs3n5ijj1cICEQ',
#  'Oe0v8onNxm-WmTkzPy7DQA',
#  '6OH4XWqAyV1_hqf0PekrKA',
#  'ZFIIG2wo5ua7c6jpIWFwDg',
#  'Dy3gsxycAonPploaY3xHcA',
#  'RZXSOh3ttbDWBfxdaaZT9Q',
#  'h-zsZBu2t3FfQaM9r-13kw',
#  'b2xcdWSyi5T8sc9vkpgb1Q',
#  'YYFwHvm7UOSHlWJ7jDFBaA',
#  'VObULPG40AIVAJXlQYT6MQ',
#  'HO64brlDTj5_t-lRR3nHcA',
#  'JmhfF3IgDb1XsJ7vPmwGtQ',
#  '_vQn4KGlWqShp5SguGSHvg',
#  'qpSUknlPxSLmGnvfEaw4bA',
#  'tS7n8itDh8A2VPbBlcjUQw',
#  '_SZ9u6LAn_KSXUe5GWrRcA',
#  'gFBNZot6rDvxjtDc1GWuqA',
#  'sQS0mRR_N-K3lzV8v3DFcw',
#  'af6mL5qJ_xkD1v4TPWKf3Q',
#  'OxLyam9aFtFNG0bOWuH2aw',
#  'JsbdV8dxqEGP5ssb9_QwDg',
#  'KC16thVX-bj-Xqp5giICcA',
#  'xTTvF0XjJ42hpg4I3BS9Og',
#  '2B3dYXiHU3JStYeIfmEIeg',
#  '0y-owmHFt3gB3fGK7Duc_w',
#  'pDOpq0wIJjhP7yK9oMqoEQ',
#  'I_2BEzQDEdohTWj03GY8kQ',
#  'V3wqAHTF46bMM62arn7kfQ',
#  '9xySKHUWE5en6C2CyOrbKg',
#  'HRkmp1E3XC3J0rKfOG_LGg',
#  'eCIjRlba7b0QNQb8kv56pg',
#  'oz5uCASmsbPUEZJQeSY7TA',
#  'wtCOB4QStI_nmsiYzcRa1Q',
#  'yqjkCiFcqmCi7xvGD0fiww',
#  'JBGfZB9hgxD-OVyu4s3nAQ',
#  'Xa18NeTCcaqAuVPB1LUFFg',
#  'TAghDWG510s7kOunS8vNFg',
#  'QurTEDQwxjujvEuHT7XL2A',
#  'QplyowDVdQWI2VPnDXr_WQ',
#  'ItDjdi6mMczhgrt4DylWew',
#  'aSxI1Mujhbuhw4lNQ2dF_w',
#  '8zrR9vWoheGC2Vx08DDwcg',
#  'vR3eM1eSk_3LwFTtEgmFOA',
#  'L4q_ZKVSJxySxm66ro468Q',
#  'AlRxtGZ1nSem1nGASDv3Eg',
#  'IN4hkan9R09OSaBR83OULw',
#  '4csOtrEyaSHM-BgANbQ-qg',
#  'qOjlwml7gEm81Vp2jGDmug',
#  '6u8k8oucpuRjUUvr7vzQEg',
#  'rk9ggXiWXf_2a3G3x6HNng',
#  'wH58iamlm3uLUv5nKQL1sg',
#  '_AjPCWOaGSkolVPn7q8Ktg',
#  '0Q3r5GporLhrGoM77hZG_A',
#  'wymuHFAU163G5ykkfIMHUg',
#  'MrX3NyiSKS1O7JqaYNnN-A',
#  'daIzTuEgRHIGRGs2kRlItw',
#  'JGLmOzeAiHzydz3eLo37yg',
#  'hYBW919Yvz9jBeg4Frap8Q',
#  'Bb8pRcDjvscsQYVOKJW-NA',
#  '6e3pkuojho0w1R3WkgwUJg',
#  'Rcd_zvRjQ2UmpnqeUx7MnQ',
#  'q7rrTfKqiyReSN7uww4MUg',
#  'GFV46TaZgu82Evjct4Gprg',
#  'UGNBEtwzgkzV5030dZNkcg',
#  'I6lxWoJ2z-Ntr97bCI0wKQ',
#  'D1ybplf_AjKVyuSkUDEaTA',
#  'z1pd3t6d5GfGmFNRuWGyXQ',
#  'nIhOeerQv34LKRbpzGb6ug',
#  'dUi8sGdQJdiBZ6zeZQbT7w',
#  'VTf1efemcGPqv_pfB8YRKA',
#  'DtQClnfivgyhxhj2iK6ffg',
#  'YJ-CTZyUtQ6anJ_44jygKQ',
#  'ZWV2h9dItC_McuukKtxrOA',
#  '4uecM2phnKELiEJ8GN9mRw',
#  'a0wGft8Zg0hDwOnUTPlSBQ',
#  'cK9e9dU6NwcCXT-ycKQ3SA',
#  'KEDm72wwss4YFXHhHdsHdQ',
#  'LNh1nxrPzGGWri54_4qCsA',
#  'XBwKc7x7C13hTeCi4ycxQA',
#  'yfOBQSg00bBE0sHqASJtxg',
#  '0uasL7MepHHQrVNgIhdG3g',
#  'bgvQI31gbK0uieMi_Vo5kA',
#  'VZOlFKHD6PEQVv9aDs1u_w',
#  'kQrCHZb5UgpWE1cjM7-21w',
#  'IWoDZzFQQkjH_JNS81050Q',
#  'MHIEpmEg_li3R7AhrnT3jw',
#  '6EiZAt37__sm2takl8HPXA',
#  'tqgDsKlKdH73HVs5jxfemw',
#  'WJGYrKVRuUTXt9ot0vyc9A',
#  '9qsezKsVNaNECLqVVGxJIg',
#  '92OpHXdGQfFBekHLfSEHrA',
#  '0zcMK5IWe1EfYY6qynEkSg',
#  'g1yLntxxyhjwfc_qRAHCpA',
#  'gX9_IO7B09C5Ix2m7OCgSA',
#  'cwellEfY_TD1LwkVl3tufw',
#  '-2bLuJsMZ0WhI9daurVQNQ',
#  'ZbSGxr0Z4guT_jn9Cchhpw',
#  'fx3TiaETzbNavgzO1HxYCQ',
#  'YB5bR4QQ4mkFPxZwbTpa_Q',
#  'jA8CF886CUkL8bV1CtyAEg',
#  'U3hzEfg9PNHIudiTEN9g9w',
#  '4awjTzxUKPzw9USEFizsoQ',
#  'WyXkVmfAgqCh2_9eKtfzwQ',
#  'qlkjrLAzVN9ow7tWreLeXA',
#  'huU7yGH5QY-Rj4Cog_I7Iw',
#  '8dgGmLne5grPADdw4Id1ZA',
#  '9qnlmW_Az2itTy0fmoE-7Q',
#  'SIE3_eOAGQku6JZJIoCwAA',
#  'HI4tz9XcUzsBu_Rs-Ks6jw',
#  'bGFUI0vv-YvjtNrq5RqIWg',
#  '9TAwitK3r6zt3-WVFDdyWg',
#  'ZM2BwmNT0V-fg66Qh6v_Dg',
#  'JrfrmXjh0RqfWIM_Q8XkaA',
#  '3xZYAwewEiwM9uwnjHganA',
#  'Ke_n08ij9jvVVEpXgRA8YA',
#  'kuFUQcBPJifsMJBtRw1ZKg',
#  'BEeGpvyh4Ufdkmf4JGItyw',
#  'BY7gsltYdGs4AhyeYxkBQg',
#  'qu6-cPbEVOeWA_ESWCeQSg',
#  'ofccH2ekJxZams0xuSFg7g',
#  '-1mjIwXWiI1uzy-8nGkdkw',
#  'zlZ43emrXIOlrffon6irRw',
#  'LpGzgTGDr12P_xUaCQ-Tjg',
#  'f1JzDDOige0bmKibRmzbqg',
#  '5Ay3tTofy4jmqgggiKxW6Q',
#  'ZEatGDrIaEDX7eZjfQlkvw',
#  'kCKoqZs-YVQAZWXoUNNKYg',
#  'euoEZArsZiB0xuq9vffccA',
#  'BYX_65ag1N9E0Qp-KcgGrQ',
#  's9VdbAOxD-PMWnG72kKELw',
#  'dhrv6GXy5otbzabXMXbOLg',
#  '7lFFFOOgHJ0dJhTxh1qtGg',
#  '7fMHy9zYXk7ygd3-KOYcig',
#  'tNQZLaoG2hHhmb8S9l0_Og',
#  'K0SCG-CrzVJ4CzKZIQYqFg',
#  'ZD5X26e3urzbaVcuFj1uNA',
#  'flSgZ7ItSLZpx3vcZXwXwA',
#  'b7g2zeeDk3JsJXI_fmJe9Q',
#  'Oo1OJbGULVqf74uGnCTqJA',
#  'dwAtKEutQKgCvb7wSSU8Kw',
#  'JfYoGjcNlK0pC9wDImHulg',
#  'b7of9cI6NJ4a81BG8AnsKw',
#  'xi109DyT11hpD93z4FAHug',
#  'p1aZIYK6YRG2hFYLxxLtdQ',
#  'KZ4JYsUbhhFVXW_nMqcafQ',
#  'lh5KqWhU03_91JJ7BtvoFQ',
#  'Ut5O_y_oE2Whv5gN16i4ZA',
#  '6CSeCnhWL8QCGPOEvXh3Bg',
#  'OXhnnR6LVt-v1riuM66rbQ',
#  'p1xvtfpcue1e7hI3SCeA9w',
#  'A48jyvMGXnEX7j0x4A2Q_A',
#  'VNkonMWVIIn78buZGQF1PQ',
#  '5555Ct3ltvyEJJRlYCzvig',
#  '6i85_hLuAdymNIy01LLl0g',
#  'VkB1stweRDqZmKoBSoem9g',
#  'vrES6mftIek_84r0ATztcw',
#  'GgR2s8ZAfFwbqjwNRlqizg',
#  '_8f_e4Gu31l0SjiyD-81Pw',
#  'CTO8KQrtlXffEmjnbuTSNA',
#  'bOMwwqgEMKapmWS525rvcg',
#  'gnzOGeI04PI6PJd8ZQVKdg',
#  'QbFcIe33XKky9ah024GuHw',
#  'GtdaqyEblmTTgPRO2XVVMQ',
#  'e755zXCj5hGy6-P-1otnKg',
#  'kCtDDd4YzCtgedYClsVIAw',
#  'd5zyrW24eeszZ6iaarx12Q',
#  'T5DTOxHOeZR6LyesUx0XxQ',
#  'OWR_lUEd-qWXljGpq9yAew',
#  'Y4KpOGpf2fmuP0D-0SB4sg',
#  'HOw1YbfqkFVOYvEqGcZ5cQ',
#  'GwwzuTbZQnXGTS5dtfPjxA',
#  '3RcE9Ni50NWUJL0gb3cF9w',
#  'pAf8pmXziGvffn7Pqch_uQ',
#  '-H49o1OyiCgTsLjsiDNISA',
#  'o6tXKd-u18X5702u0wP6Dw',
#  'dJuxA0paONof3QiMAN8d7Q',
#  'erilrfq0TCOU5fHUqITyYA',
#  'qPIgJDUf6Zh3cocMnU_9Aw',
#  'ibww7uBdyEwDb0ifYbnffw',
#  'iTcf6h6MFULjvaA3B1A5tw',
#  'DPQnTnNw2PJj7DdENM98Cw',
#  'r8R8w0YZdfwghP5rAJk0iA',
#  'OrgAynTkzP_jx2MEj6s4Bw',
#  'KBHUaVmXOs-Ht3lB_Cnz9w',
#  'wXQYt6rxs8B1gcrVeHpLMA',
#  'n5XbK4x5nMxO6JudyT-1Yw',
#  'Cp1ZBUJOSg2BnxCjV0O6aA',
#  'nbvQ_DzBK23lk3cdVSOYbw',
#  'y76vgwHJRWvFslm6OUw-Jg',
#  '6VJXyeJd_tJU2MrryUjNTg',
#  'z81Z5bUPd4wTBhzhbtrfwg',
#  '7dG046T45h4eRwKsI26-vQ',
#  'ABR1Naam5qa9ufKr4NvoDw',
#  '0vvS_vTunCDjbnekWosVrQ',
#  'o4uTg7-On9r_oiJ5xuZwgA',
#  'tDKP5fliywfNc8yNt7UYsA',
#  'GIS67TxzRessKb4QIlMitg',
#  'Ct9bd1DzNjAYLeDeIqmAKg',
#  'Fmxp7-_ZXfCvvQpX9u7CiA',
#  'z_7uwrP8Yj9gQ-uXHbeGTg',
#  'LxzOnuL4FKQ3X61TlNPVhQ',
#  '_quVlmD-dxLi3y3k8t1izg',
#  'EJCIWlH1eUnThIMROAkLYw',
#  'aHLPCrs-QltXH8mGJcJvIA',
#  '5CXZjwRQlbEWQm5D2bjhmg',
#  '0_L8UlbIWSi71KmqOA9_jQ',
#  'vatYVMMNtaw7E_PH4fQEKQ',
#  'ILYKoi-CAwa6VAg6n1cHUQ',
#  'wgbZEx298Lo39mtRaRILmw',
#  '9GbKOc9JHwdIJVNj-SadCA',
#  'mVdAUzhLVFzLZCSUBvBqsQ',
#  'YxsIEfjWBgxMS8FTvAulUA',
#  'qF5jgWExY8zjKiRzQ5aaIw',
#  '4NePLd3DY6Fmfm_OtoYZ-g',
#  'ofVYM5oWccGKhYgD4dng5A',
#  'Jvzprfvw4d4shADNZuxVnA',
#  'jBZeFW-ovmU6RODGjMTLlg',
#  '4EjbWDppL-3zl9yUCyt9ng',
#  'xoXHvJagC_mZmh33uCi7zQ',
#  'oroBBOpAdWosXLeDwiNEXg',
#  '7l4QfJ1xLo_z2XpMQip_ug',
#  'Hp0v7FKrHtRceJja8Ig55A',
#  'yNkOuXH7VdDjYKqV5w33PA',
#  'UCMVrwBLxELr5sS5nuNRvQ',
#  'taMiJxjNOvJbAPbu_0PfXw',
#  '1jdZuhFDFiAtgZIo4WyhEg',
#  'VMz4qNV3-MNgbt3Ejeqw9w',
#  'EnUeNIuuNAdDARJaoG0T6Q',
#  'r9KdTsZ1RvVGYayqpJHSYw',
#  'yxx2eSxC1g-LWcLRpYJeKQ',
#  'jCIyyUPyq2Fy54qTADb-bA',
#  '8LYul-0GwtmoYOoXX1fpwg',
#  '0NRpgFl9N1cbli_8P-d2YA',
#  '4uypXgVIYTTkd6A7gF6hBg',
#  'DX5YxQXzV6NTyC20gxBghw',
#  '_trER_To3Vqn_JsVu-FgIQ',
#  'fpEB3ImOiSjO94GmGu5x8g',
#  'l79ACsMSAzueI7d0gff6cg',
#  'y0u8Q0O2xvhGs165VYZ-6w',
#  '-28hEE6AcAUbJctGwvC9kw',
#  'A6_E3f10rQdSUVKiy-y4QQ',
#  'MuSduinMK-f2UJ7CyIjdkA',
#  'i2nu8bBlyejnio8DHWIUcA',
#  'Cswsfb0_uSgwHxyHMqFKwg',
#  'uowaUiM3WtW9b_EoATrqNg',
#  '08UqAmPMYHeOIfiumghVGw',
#  'P2CPKupGaafZ8aej1xgZbA',
#  'BgHctkgsK_JJISN_lc4deQ',
#  'jt8Yr5UGMvm2fXjonpZamw',
#  'N-mVM_C_qQS5Tl2loTkIfA',
#  'Je8Y39Uk0PsIPELbxR4ZWw',
#  'svyvi7jMnRebZ1fDJIQP1A',
#  '7f50VCFvceygnPPVgqi72w',
#  'MKrvEEejLBeUsjZRBtVxrQ',
#  'XbPs8EnNMof0VNDMnkUy_A',
#  'CYk5MGvIfIzCiZP23emXNg',
#  'gLXYCzTxWkekCmg8rBoQaA',
#  'L7MrKZ2ozIe0ujb3em_0jA',
#  'rmGmTnpJt7pSjezPy1kcig',
#  'UZNkvZ7zhnobmO7K9Vmcsg',
#  'QS-MnXNK5gq81qIxwq4ysg',
#  '6BKHJ528fNyOabaMUbJ7Ig',
#  'VZ5lSNVTfmSpgH-MkU4BWA',
#  'N3cvGSN44dONNKew_yECxg',
#  'AqUGDt9A3NLkBX-cKI2MNw',
#  '0q7xJ8fRdfHovDRj2pQ3pA',
#  'B2UL0K675UP8KGiSYVi4GA',
#  'DcLMcWqX6TApmep0yMBOHg',
#  'QaNfzjAecuJXz1Je8UQhEA',
#  'dHhYOKM2FE1iDnCkBM77bA',
#  'eVhjgyyl_qe3ao-2g7Fiog',
#  '1BWGgA_omh3i4zeXX5sqkA',
#  'avos1rGg2AqfC72Gl5zS7w',
#  'mvJCdT2YcQiEyldckjA0uQ',
#  'mf3TR7YAo1ePyXgJHWGAMw',
#  'y06YVuJI3_QKRKSMfAN8_g',
#  'B-zdFy5CvAHldMSuoImMXA',
#  '_7AiEOKxaXSxPjsGNou1tA',
#  'DMhXdTgavnf8byxM9jtTsg',
#  'jNJC_5bD5F2NAtPBWpFG0A',
#  'UaTetr5VVHboaUON8VhC_w',
#  '4zMxGvNBkxC3MopBDcUhig',
#  'VRPWvul3zvvvLR1rHGm0sA',
#  '7XteP8HUSEPnEN73xlKgEQ',
#  '8KIt3yDTaz7dY_bKViQ3TQ',
#  'CpJUzW_tDeSnryolGnU3dA',
#  '0GjNSlipzvsWgMeyyWRsDQ',
#  '7g0NLyo7a6KnNHBPoWfUiQ',
#  'vggpLujk_4Myl1KxQH-HWg',
#  '9C_mnDJKcDzE2ONFMDJ9Rg',
#  '8WEBfnSn_trbcsWgHA94Mg',
#  'cBCcZnSTALUTP902jH_FzQ',
#  'uxwJ5_VLBfUWMew3kWuvqQ',
#  'l3ah1r_a9Gw4PpYncllffA',
#  'aEk76knbZRbpyC9LvBToFg',
#  'z9bq8vmg4eRYYZbAEmCDrQ',
#  'ANSoC9EzEfojvefWWveAqg',
#  'O9NxZv03ZpSREYpeoZxRSw',
#  'U3qcaexbMzxmxoiUcNtgoQ',
#  'rY0DMG42HBXHC79WQwZsCA',
#  've5Lu31Z2peI8EDh8fSsPg',
#  'QYvpxHoy-X1oRDyibTExwA',
#  'Q-QeKF2v7Q-rN-kQ5KmboA',
#  'BulT-FSHdHA7M1pkyua4IQ',
#  '8TapxIxtzS8OzIIMpdqWjw',
#  'Q3SKohJakvPzo0sNKiEoBg',
#  'cfMa-W1Gh834KT214a79eQ',
#  'GOBCc6oHaozcZp6x3P1Jvg',
#  'iOlS0uUFPB3vsMNs0HJVAQ',
#  'UIsFv8UXt2mfHnta0_A_Mg',
#  'pCUVy8T5xEEi7EVqgZ35PQ',
#  'onBe_9kLCvAYnXBYOXNWhw',
#  '740Q3y1SCcyWXjfW0gn1Ug',
#  'gf3NHw1bw8zaTkHSi2x6iQ',
#  'xQuz-tpHwPMa-fxoqj-TuQ',
#  'rlbwIlHDqCzyRFiG9GbXYA',
#  'cmw_B5oP5haq0GWkPSMGNQ',
#  'HCNKxd0J0pTxAMJwNuYmrQ',
#  'gwUKjXza3fcdtvBTSXpunQ',
#  '5Heya5sQcGNdLI_IvEhzXw',
#  'nqnm7EJ9EH00zk2dGQ9QKQ',
#  'E9yJ-dGaCuBV6fLF6MNkVg',
#  '3AsVqnT11Dh2joUhrnSUPA',
#  'm8o3OrY0DWfqvk820EyrxQ',
#  'MeT58u9wjpvgWbWBKxKMzw',
#  'BDXod8xpyhjzePWDgdVhtA',
#  'WKI4p-Fjq8qRwKSP-aJOHg',
#  'uM_b0g-d7zdfGh613dbxWQ',
#  'z4K53c-5FMSkjyuVvg5MpQ',
#  'hpfSnumy-8ve2U0_cs6b3w',
#  'gA8M6N0C1EAgIVryalYbHA',
#  '5XCecD_kHmAYv-uVe-oJfQ',
#  '-P8XwS4eYAX0HpXey7ECeA',
#  'RD-MBCQcHIzXe9RZ2_KfhQ',
#  'cMdP-xB1D7VJj0Enxf44Xg',
#  'xpH74K4GO_PUyJLG9ZCa-g',
#  'xJigQdulvYC1vj3t0dm60A',
#  'RLmXioxW1JdzSHTecSGSuw',
#  'vqcZ3XyAJix1xYjG_vXBzg',
#  'PrNdvlxp2E-PKqQTy6IGfA',
#  'B2zOSG7TMyZb48AWjwWyWQ',
#  'ufzbtlL7JxYwgb8w40rMcg',
#  'ziCYykfNLy3fpPSHuc5FFw',
#  '-nsVjP14sC89P-ZZOHhDCA',
#  'aphuHjFYn3Jat89QzPkuvQ',
#  'DHTiEQgGr1KtUDkjsUI2CQ',
#  '7uGsMlo8_uIZIITKfhEARA',
#  'PSGITC6w468vKEKxvw9wUQ',
#  'Fv9skIAikwPKkh7sHpHVug',
#  '1xJnn0Gn_TTSh9VeUjyaZw',
#  'qwoxVl7ZjE6ViB-UQb5bYg',
#  'KSHbL3GMhO3S4pPRgLVu4g',
#  'TrFC-sLp6rtkV62BRqUYAQ',
#  'ttlbqxlTbwLXoQx3mmdHDA',
#  '45tNjB6CxYW407ejMLUsxA',
#  'sp9OnX6irdwJ757I9KB2sA',
#  'VrrSZ4KwAEV75jqVL-F9Lw',
#  'c2EfZuhjfwJ2VxTkTRv9Ag',
#  '44iSrbh841O6V3UjWFgKpg',
#  'Bd8LI1UO5FFAtIQIwqLc2A',
#  '0Tf3SbtiT1vxhVYgZPbtLg',
#  'VHOxagY8nQhb40iZIFUKgQ',
#  'jQShahssYuCqp_rCq1vNkQ',
#  'K9fVcpk85jNxEz1mUYcSIw',
#  'E2eZhVfICDQtA5zpgEFJ0g',
#  'e6frTAikgAc5LIq8fIs98Q',
#  'Kt66MjxdjQcR2d90-NQY7g',
#  '9qWjF5SiK2_MGnu6wBcp-w',
#  'evv3tS2UfbppEIqR8us_aQ',
#  'wH6hivXJebodb327MaKKww',
#  'P7Koldil_45SKSHfsmueRg',
#  'B_DCj_B5xtPsNQyjzBssRA',
#  'yVpZWU-pA8WECj0oR6GDdw',
#  '_mj4uLg4p0K6Mij8P35JlA',
#  '2teTh-s_j_5JxXdn70T8XA',
#  'd6cOVwwBqimgOeoJNS2f_w',
#  '8FA2OwiBnbwmpRseoxU10g',
#  'PmL4gFlcVN4mS8jc-eIERg',
#  'OpqN34FYxX0Ai9VCjQUVMw',
#  'dzyEGGjutn_mCEQ1toaD2w',
#  '8-Y0Pxt5afQCYBteMBhYiQ',
#  'aTe5p_W7RadkXgGIFHASrA',
#  'mILLgPTWueUh6CJOwLGdDA',
#  '9T9bwdOdIqdQcIYc8i-8fA',
#  'JAvkX_nlc1ffGgqvgBEM2w',
#  '5mu4SWwVTgNUXw0lWLaoZw',
#  'id7ZwTSuUIcjh3nVVQkIEg',
#  'bXRL6S6K0Az26WmUDrrtag',
#  'nwNBSFooLZWn6o9_ahhfUQ',
#  'K4D60pEZ-9OiwMPjzgQ8Yw',
#  '9dxEeDDx01DA1cETRm-Mew',
#  'xoLQvLVBwvOrb-Os0I78PQ',
#  'NWwBrQBLYXwe-EU860rfAg',
#  'tqMrdEZ5__nBBQLA3XukRw',
#  '5qi1M7cjSld3sibYue6mJQ',
#  'Nx7Uony02V4E2lUIv6l8Ig',
#  'oVx4FarZkIYo87b8bh5QKQ',
#  'TponXUIK378LcV_a-rerHQ',
#  'yKQK3dd26CfKGKK1pkiI9g',
#  '6DRmW09-hUXmPqkhwaF3Bw',
#  '_jV1BCf0tuDzaL9hHxSeyA',
#  'MUEjEJ2JoJeWDQVqfPnsAw',
#  '66PPr3GSxoPDgNWnTyEW8g',
#  'WnmpJk4Hqq-7FvneHurB1w',
#  '2298JW7CZlYMcD8S18TSLg',
#  'Ul74pIgdWyJWXgcjxbcy8w',
#  'qAkHrSdL6UqKN6Wis42jzw',
#  'NKKDxdy14y7OoSMgEEHVgw',
#  'Of8YfS3f84M32u4hwdvYJg',
#  'iCxCxk3vP8YfIGRmJoyuxg',
#  '3Oazp51oSsPADwfGOWKKfA',
#  'iFMGWKc-EA6U8OFFreEHiw',
#  'FpxFNBdL9V8Y7xN6fFW7kA',
#  'ydNvykJiKzfg5KsS15ARVw',
#  'iWjuG3ZfLGVTj7nTutGloQ',
#  'deIQYQS0lB9dtw4ObJrceQ',
#  'ufcf9VJn55RLDYGWsYDxgg',
#  'csnHnE_ns2D2zzMWz0DAaw',
#  '_vCVc4KoHG03RznJzRBWUg',
#  'mLA7V2VDQ9u1rTR_hSM-1g',
#  'dEGx_MMrelPO5T6FXklHOw',
#  'p_ngRK2eFQJ06qZ4Gmvb5g',
#  'YxBQHZCjnVOSdxbRHfxOaw',
#  'oYAQ03CHJ4jCWsS9SDP8Fg',
#  'uHpkTphGgIRBsg7Me4gz-g',
#  'pIBX_IBixagX-2AzFPl77g',
#  'eGIvKJEkCgaEvraeHo3Puw',
#  'TEfmUsvRZWB7XA85ZX7haw',
#  'iSBC7ZDjd0lqUy62y5_g_A',
#  'K1EE5xRuFWX6P7SpItIWSQ',
#  'iiDcNDRbcOwfbB508qN63w',
#  '6yv8X9ayXUwGtsXtIE5OOg',
#  'Ert-WzFNhkcAk3L3U4TXHA',
#  '9sX0PzKiKZY0a3Btf5Yf4w',
#  'g0tCaTqUiDDH6PaIUZu95A',
#  '9CbdFyTNs-GhUOT3w3Ck4A',
#  'U_0dSLlH3k6gt2950cHLhg',
#  'URSCRcwJ5nK4E6az_P8ryg',
#  'Lt1P66YZU_kJnaDgKB7dgg',
#  'aoyvZ1msYCRU0d0gR-7Iig',
#  'cfl8LuQ7VleSQzTnFedyDA',
#  '2miB2BQBvRII4Cadp3HSGg',
#  'y9EZmvMyL3uI4KGAJuu23g',
#  '6HM0G2UfKzzGhmvKAJ0OPA',
#  'p2soEzHoKX1iSGm2jv50mg',
#  'b9YYhVN3DIbT206QDIxbHQ',
#  'ZiVR0tT-CPtdD0fL1Ps_XA',
#  'ydmS25Rxd1YiE9T3uSvCGA',
#  'ZsP6yF5QprRJAINRvcDntA',
#  'aPKOQdyJmXsin_PLAfKwhw',
#  'RoVfqO_Mq6pG2QK1ZOndgw',
#  'j-o2zGhifKb8JSdgQufe6Q',
#  '6YP4lbTEICqtQhaJrrn1vw',
#  'YHeYZe4zPcEJ_Ph1hvfAdA',
#  '0MUrNfwuqLyBI2UFZ_EvUQ',
#  'kNnFjsxNv_OkvK4GLRTBJg',
#  '5aE6Ph2-IkRNzR4T559rCA',
#  'dj6ezvQ1ULvqgHQAr5LF5A',
#  'ZFKHEkILACOvAXu0jP8ybw',
#  'EX1gsltdQlS55L6_GwlG7Q',
#  '1zEaR1zGWrBIKKrJiKF8PQ',
#  'RwiE6TfnvJn7ujSpW-1QfA',
#  'PNh-yP-9UYYw3OZ_QHteQg',
#  'jtf8jKlR-KT5Tm4BAPAsyA',
#  '2eljvfKMQkqFTp2XpYCycw',
#  'psPIP9DFPRl8wC625y0vAA',
#  'r-8Pz9GEvsKNCVZhPwWREw',
#  'DR30lzIHVTF6xhyMI-3IlQ',
#  'tKffT8a4HFQg_AAzzRmeQg',
#  'iVLXDYgI1Uftw4WezWBuOg',
#  '9pb7zv5dF5mNYocA91M-NA',
#  '89gr564KWwUQBVW-faLe_w',
#  'XV9FPU7ylz-NFQI9BCNCVg',
#  'YPYKnD3uVnTqZUF10v7Vvg',
#  'Fvzd0pxfGC8uir1PNmO1Pw',
#  'ecki9ucf3WKqRjuc3y7nCQ',
#  'IlGba2NVZoQH28zEUZAX1Q',
#  '8dHUAS8T7OGxv6w5oVo4ew',
#  'HGh5Cs_Vo1lnHZcMBE9Dmw',
#  'c3X8LSEJfZsu55iNaipTWQ',
#  'mOjwSyMNjDwP5X6smYmVMA',
#  '5S24lTR0S31DGr7N_B-kLA',
#  '7lpR_QmgJVg9HxywpnWmWA',
#  'jdJwziOX5FB2C2D-vESY0Q',
#  '34YwmimX2PXqFlm0p18jyA',
#  'TbgxhIPril6PucOW4O3sUw',
#  'Z1p1XRy4IXo7ybrC0cyWQg',
#  'OZAVH8Mb2CGnMSItxw-Pfw',
#  '9gJtP25_APqgW8EiT9aB-w',
#  '9v1qinjsS111lT0m29emsw',
#  '7eX01e821qiLbvoQQpNmIw',
#  '6YM6QTJFHP5ae1ojZsTm8Q',
#  'grSN0H84yM4a3Oyy5Nfm-w',
#  'DZXFEwlwu19A2bj-mo9oqA',
#  'qIMgYEui542vapZdq-VL1Q',
#  'kOpOC3DXghd5c3h_2VIpEQ',
#  '8mugg0TW0shfu02VhoG3Wg',
#  'yiv9z_p7WTKCZ9sMi0j2sQ',
#  '5mLnpk7lJuZ8baMGZhwa5g',
#  'dXSavn5rYcQl9b2U_GuJxA',
#  'xm0fbzwr2O_IheiaD7eiBA',
#  '2zQaLJEaNeFa9ry5mn48_w',
#  'c3sC65Bl0gK0o6d70oWpQA',
#  'MYthzr2pBdxH2Jg6oxa9bg',
#  'M-mzuR6PzEYpLSBDRVMyEA',
#  'TGvTBtJLdRazDM3x_9BNBQ',
#  'j4Go1BQpeREgMKZLNuLPbQ',
#  'PRifPEvLeszt9A560qi7Nw',
#  'u7U4RtR4UccpRswgNOhlXA',
#  '7CcWf0Wl7AidEzLDUa6lJg',
#  'ems34TUVQL-TvRb_sVIptg',
#  'V-M2-MzrdoLKPPqErgJHog',
#  'Fsyw5fQBk1oX4ti_WnbbGw',
#  '59fc14YwNiUojGBz00_9bQ',
#  'ZSBk3x-mFaZdOBw0jCS0xg',
#  'ZQW_jxK2T2wbtp81bzypeQ',
#  'ZQbj092OFFOPrnACgTOjwQ',
#  'xrIpOe1el6K7AD_63qEnBg',
#  'Pi5Z8kxMUWeZRulnIBmkdg',
#  'mOECD2v-ukPQ4rWqOwjTUQ',
#  '4HMZvn76-QeaoWv_Dqir3Q',
#  '9rRLFoKblSs4q_QbjQ4v8g',
#  ...}

# %%
#link to review json 
from collections import defaultdict

#miscellaneous methods for retrieving 

def get_reviews_idonly(b_id): #get review id list from a single business ID
    '''
    input: business_id
    output: array of reviews associated with that particular business_id
    '''
    review_list = set()
    for row in reviews.values:
        b = row[0]
        if (b_id == b):
            
            review_list.add(row[4])
    return review_list
    
def get_reviews(cat, business): #get review list indices from review json for a single category
    '''
    input: category phrase, business dataframe
    output: array of indices in review json associated to a particular category
    '''
    idx = 0
    array = []
    all_reviews = set()
    cat_id_list = business_id_retrieval(cat, business)
    existing_ids = reviews.values[0]

    for i in cat_id_list: #for every id 
        print(existing_ids[0])
    return array
        
#get_reviews('Fishing', business)
print("hello")
segments = dict(list(reviews.groupby('business_id')))
print(segments)
#year_distrib("uYHaNptLzDLoV_JZ_MuzUA", reviews)

#unique classification issue - i.e. "Shopping" & "Shopping Centers" fall under
#different categories

# %%
#DATA RICH CLASSIFICATIONS
reviews.values[0]
reviews.values[1]

reviews.head(3)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9c82537fb06a> in <module>()
#       3 reviews.values[1]
#       4
# ----> 5 reviews.head(3)[0]
#       6
#       7 #print(enumerate(reviews.values[0]))
#
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\cdchang\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 0

# %%
def year_distrib(b_id, reviews):
    
    #get_reviews(b_id)
    
    segments = dict(list(reviews.groupby('business_id')))
    reviews = segments[b_id]
    
    dates = {}
    for row in segments:
        date = row[2][0:3]
        if date not in dates:
            dates[date] = 1
        else:
            dates[date] +=1
    
    return dates
