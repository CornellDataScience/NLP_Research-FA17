# %%
import pickle
#from utils import * 
import pandas as pd
import numpy as np
import json
import nltk
nltk.download()

#import seaborn as sns
#import matplotlib.pyplot as plt
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
def json_df(datapass):
    '''
    Load the json file and parse the file to pandas dataframe format
    
    Input:
        datapass(str) : directory to the json file
    Output:
        df(dataframe) : pandas dataframe object
    '''
    
    data = [] 
    with open(datapass, 'r', encoding='utf-8') as data_file: 
        for f in data_file:
            data.append(json.loads(f))
    df = pd.DataFrame(data)
    return df

#business and review json files --> dataframes

DATAPASS1 = 'C:\\Users\\cdchang\\Downloads\\yelp_dataset\\dataset\\business.json'
DATAPASS2 = 'C:\\Users\\cdchang\\Downloads\\yelp_dataset\\dataset\\review.json'

business = json_df(DATAPASS1)
#reviews = json_df(DATAPASS2)

# %%
def display_topics(model, feature_names, n_top_words):
    '''
    display topic with n_top_words in a decsending order of weight
    
    Input:
        model : directory for vectorizer
        feature_names : list of vocabulary 
        n_top_words(int) : number of words to display for each topic

    '''
    for topic_index, topic in enumerate(model.components_):
        print("Topic %d:" % topic_index)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words:-1]]))

def load_topic_model(vectorizer_file_name, topic_model_file_name):
    with open(vectorizer_file_name, "rb") as f:
        vectorizer = pickle.load(f)
    with open(topic_model_file_name, "rb") as f:
        topic_model = pickle.load(f)
    return vectorizer, topic_model

#pizza

path1 = 'C:\\Users\\cdchang\\Desktop\\yelp-topic-model\\model\\pizza_tfidf_vectorizer.pkl'
path2 = 'C:\\Users\\cdchang\\Desktop\\yelp-topic-model\\model\\pizza_nmf.pkl'
path3 = 'C:\\Users\\cdchang\\Desktop\\yelp-topic-model\\model\\pizza_count_vectorizer.pkl'
path4 = 'C:\\Users\\cdchang\\Desktop\\yelp-topic-model\\model\\pizza_lda.pkl'
vec, tm = load_topic_model(path1, path2)
vec2, tm2 = load_topic_model(path3, path4)

# %%
tm.components_
# Out:
# array([[  5.35318219e-02,   0.00000000e+00,   4.09802948e-02, ...,
#           7.96897006e-02,   3.98538679e-02,   0.00000000e+00],
#        [  7.86209423e-02,   1.88202333e-01,   3.27705625e-02, ...,
#           2.97546372e-02,   9.73259392e-02,   0.00000000e+00],
#        [  3.54345514e-01,   2.62719244e+00,   1.12437870e-01, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        ...,
#        [  4.13455229e-02,   0.00000000e+00,   4.27813136e-04, ...,
#           0.00000000e+00,   6.59642074e-02,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           3.22001617e-02,   1.51870707e-01,   0.00000000e+00],
#        [  1.37329447e-02,   0.00000000e+00,   7.26685010e-02, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
#k index embedding methods

def get_k_index(sentence, vec, tm):
    '''
    Given a sentence (not the entire review), generate a distribution of topic 
    by adding the weight of topic per words.
    I initialy tried with the product of topic weights but ended up getting 0s.
    
    Also produce the probability vector by scaling the vector so that the sum will be 1.
    
    Input:
        sentence(str) : a sentence to be studied
        vec : vectorizer object 
        tm : topic model object 
    Output:
        k_index (list) : the vector of length k (k = number of topic). 
        prob (list) : k_index but scaled so that the sum of inputs becomes 1 
    '''
    analyzer = vec.build_analyzer()
    topic_words = vec.get_feature_names()
    tm_mat = tm.components_
    k_index = np.array([0.]*tm_mat.shape[0])
    for word in analyzer(sentence):
        if word in topic_words:
            k_index += tm_mat[:, topic_words.index(word)]
    if sum(k_index) == 0:
        prob = np.array([0.]*tm_mat.shape[0])
    else:
        prob = k_index/(sum(k_index))
    return k_index, prob


def get_avg_k_index_for_doc(doc, vec, tm):
    sent_text = nltk.sent_tokenize(doc)
    if (int(len(sent_text)) == 0):
        return []
    else:
        tm_mat = tm.components_
        k_index = np.array([0.]*tm_mat.shape[0])
        for s in sent_text:
            k, p = get_k_index(s, vec, tm)
            k_index += p
        return k_index/int(len(sent_text))

#use this 
def business_id_retrieval(cat, business):
    '''
    Input:
        cat(str) : category
        business(dataframe) : the business data
    Output:
        id_list(set) : business ids of a particular category
    '''
    id_list = set()
    id_list = []
    idx = 0
    for row in business.values:
        categories = row[3]
        if cat in categories:
            id_list.append(row[2])
            
    return id_list

business_id_retrieval('Pizza', business)

#get_avg_k_index_for_doc("uYHaNptLzDLoV_JZ_MuzUA",vec, tm)
# Out:
# ['HRFJlSAP_EBU_MpPPmpUDQ',
#  'BvCHyg0GtxA6XKmRC0cQsg',
#  'weXoqWqLgzMOf5Yz-qiujw',
#  '7HFRdxVttyY9GiMpywhhYw',
#  'G7QZWVm-ytyKHpvUq3ggFA',
#  'KTai0Sc45p4A-j2RYoDnHQ',
#  'DAMTCTsSeACXbkSABkhZqQ',
#  'RzVHK8Jfcy8RvXjn_z3OBw',
#  'c3Ax5jq5kyekKWUgiaVJSw',
#  'EPkV2_H0TRcARa-2IFZ-2A',
#  'vIstiRtK87OXR9aT54_8qQ',
#  'RnWZegos0nAjpPV00PPxBw',
#  'fbLYRHIZAt3q839whhaBUg',
#  'wkhxaIt6S9bQ0twAD9Svpw',
#  'jW4-bGuymLGlB9OBsTq3TA',
#  'L4PI4kh8plShtrcWt6aBTQ',
#  '9DHE9JieR80pYkpyr19iZQ',
#  'koqazXBW7wAZVry72u5vEw',
#  'veU3mhOn8kF87VfE_JvKlg',
#  'nzbQXU2x7O8oucKGthUT3g',
#  '2LVuwl-eH-8PYikyFmqcTQ',
#  'F6Ujpp1Kh7L_3uUfoUsTlw',
#  'le4fLtpLE3PdGnqRFr537w',
#  'CtYWpX_cy1YdZgoKtS0Tqg',
#  'gKXsFVhWyK7MLQhSKG5_mA',
#  'MhINNBBwzGn4-n_YI67wog',
#  'Zv77o3aDuNDY0t3fCU2ebQ',
#  'gqGrMnDYEToXOYajBuEvKQ',
#  'LwQB9H3jZ9wTk24Lr-AnZQ',
#  'dD6JQo5tCNtOtauaLaT0sg',
#  '1NyHpXJqSLHnvDCOW0nJDg',
#  'YQ--LJ7pvjiDSqNv0TuKTQ',
#  '6DCTAExBd7sp92BcAl80Qw',
#  'qpm0gm7SdsY2LnvXzQb_uw',
#  'OgANEur7Bt8YJSd2uSm6yA',
#  'b7pkopqvDr7A7S7hlqp6cw',
#  'XWNbd_RDR4lIzf_XlnUqpg',
#  'kihL3ob1VOlAaGNeJ0fClw',
#  '_XAaKm6lN5aQnPUWTmjonw',
#  'BeqWMUzFZCqz8na056XFTQ',
#  'QN-Jwhwvv3ZGTg8bXZXAyg',
#  'Sr1b1EK8Ky_c3hCzvjtftw',
#  '9b-rXZbHAAxv_0sSWlcyEQ',
#  '5X3dzKWnBdV-KmxdGEPb_Q',
#  'UgWVMUWFrr6bt3NSfuKrGQ',
#  '1pOqoAixFXrVci0kSZnbzQ',
#  'Kd688LtN-SAisyZnBs2VhQ',
#  'OX6oIIr4ELW8aRjbHjXYEg',
#  '3fRRzgNdmGS4F7FiSBtRKw',
#  'hLu4q64lPvF--9gd58lcPg',
#  'WYxSlAMiQ2NB7Ns8NKTTAw',
#  'NOKaVqvi4hI8RgGjFCFIAg',
#  '7KB_fvSCGJQfq0rFl4_ecg',
#  'JT9krwpag1O4YRjJy_ZA6Q',
#  'o75ipeJO4E0Pfvq39jwcQg',
#  'j5rEA87TL4Dqd2SdivgUeg',
#  'sEVa_2Nlo8CBPGOTE7ubgw',
#  'a_J54DOnr3lv6rWRLYGj4Q',
#  '-3oxnPPPU3YoxO9M1I2idg',
#  'XvYwUnuWEai7p-95cj8S1w',
#  'WexIGFr-I6eH4loUY6DILw',
#  'LiEx831W0T_Fx2M9-m42eg',
#  'xFCfqtyoIfFSMJbL39jnEw',
#  'PVHC67qH2d6DonAGRxvymA',
#  '5PpFojIpkGV4JoUP7XJ_Zw',
#  '8995N0iamENbaMr6lKcqUw',
#  'MmUwlfRrxVLON3NWOobC_w',
#  'AsL41PPAeRkPwRbxLGjs4A',
#  'vtkS0upk1685cCk4dUWrCg',
#  '_0W9-Gkjkcct8vcStBU7iQ',
#  '729grSa1Wsn-hfv7D5uOxg',
#  'SfHE6qK6dT7wxX-Ow82tRg',
#  'xeCqEmjQi0M0dlf4DXcugA',
#  'wA2xaBsT8d2opW_jYe1XLA',
#  'ataRn8s6owt3SObGajp4KQ',
#  'Z2cyw4t6zU2g20lOEFaO_g',
#  '4itFChF4I-d2Mkleyh-tvA',
#  'b2VDp4P-5CXbvS90ewtXkA',
#  'osx4izO3hitWQTa9yPr6eA',
#  'h4zdQoZZfXZGkR7GWD8O1A',
#  'NQoGxONQIBEJR2iXL-xaQQ',
#  'p_o19-gYFD1ewixxIV_HAw',
#  'ykAYT-7tSu9kiPhqxjWTrg',
#  'qqJkYCUIzGvmtOVtnxznfw',
#  'RMEzxhYfpnEsWlfozit_xw',
#  'M-5I4Wwa79lXsYlJnzDwgg',
#  'pZbf-H0BeOrsnJu5wjlM0g',
#  'efMDX68VIiVcYE4Rd14bXQ',
#  'xJ94FRxbFwkmpi1hjuWlaw',
#  'PepLYiTk-2j6Nb8JFVT9gQ',
#  'a9usBo16KZ-gxOJXdryNlQ',
#  'JCiglfoF09JqfR_gn6XYcA',
#  'cPbkt2C7CVgJHHhWCh1m2g',
#  'y-Iw6dZflNix4BdwIyTNGA',
#  'WEv5UoT2W2lKDq5ptXEniQ',
#  'PmkXtqIcjQGpNShB8yTSrA',
#  'wUsuktjmVIsUeT6ges7YkA',
#  '4txqE_5DJB6JDzH8Hz4VtQ',
#  'hsbtcqamJjmL6ASCAWnQVw',
#  'sxXn-KmsJwJZLSGio_m5XA',
#  'cdsxkycC_xrXlOdsm5yZUw',
#  'RuU1P-CW3DJtiLoNTahUHA',
#  'UsFFaNUWG5u7f9rHpJBHRQ',
#  'EluIN94_26TTrTdtGI2aBQ',
#  'UQW34W90XPb5nCGBDVQPVA',
#  'caUPXiOxvLGMsorJBtNlhg',
#  'Qy_FDRtL-f-syUlEKpg_6A',
#  'VfxlkvZQkLr9tu_w1SU_iw',
#  'K5TwSfhksW6o9XKmLI3UYw',
#  'jcWj08t2Ktjl_cYMNhNcjQ',
#  'ZqJWyeb0ApL25eiA1liizg',
#  'ugr3e-42ZVzaVnNWOH7JDg',
#  'drn7B6q9_LsUfUbgpgxh2A',
#  'A8bgJj03rOioaULr9TZSCg',
#  'lLMJsTchKYF1O0fpNWpCRA',
#  'x1Cd2gSPZVeNxDPzzqlClQ',
#  'GxfgOFgUhv2rfr3FXVWfCg',
#  'wx7fvfCq53tNFieI4FiBWg',
#  'JblPlNFZz5K24WJ5YlZykw',
#  'mo78R4hiF5JDcxpnLljEXg',
#  '5Eq-hllRQnae4OY6sAzNOQ',
#  'xNzD6FRuz3N1uz96d05VEA',
#  'UGhkyixEmvmh5chgb4VshA',
#  '416PofBnxY9lgjaU_EgisQ',
#  'BnXUUv_s12eMbYWds5wjPQ',
#  'AcGRSWCpb7YB95MTsHlGEw',
#  'i5EhA_T8_eWLr4_4DGDS5w',
#  'Sb2a5N9gSLICYkMVSjszsA',
#  'MSc5pybthcvHa0g_lg5wuQ',
#  'papMvgFSTh3hBb8junt7CA',
#  '6-gL3PfW1L_hAbH56LXqJQ',
#  'cyeTGR2pBJVRx79ReY6mcQ',
#  'y6QP5IrOJ7_FsB51jN2_Jg',
#  '9xjAQ9VlK6e46xy_iLzXqg',
#  'ApHiz1xxENwjkp8MKrE4Dg',
#  'joCwkZdnpj3R2It1nDqxdw',
#  '0X4D58d_nShvVeN5FeYiHA',
#  'hX8XeGwSxGgEatWt_ISywA',
#  'YIW9EccX6isxy5NE6D5wSQ',
#  'dyZvfVtD_5voybaxnPPXhQ',
#  'htNNxttBjRmRnP4d0XFl-w',
#  '6-gRHn1n11ATqWBrFTLnNA',
#  'OXSN9Jrp5JeF5VnXpDNHpg',
#  '0UK5wLZBO_wmxHN840zSAw',
#  'EYKDklUoHuZ4g4mjx9q0mA',
#  '4sfof0u2L7_ryXQusDM-aA',
#  'zOmz8CM5SVFGklGRSsV5mQ',
#  'bD3r0YLPNoEYsDaPCQwkVA',
#  'iY-qwquw8Wd4yphXnhnFqQ',
#  'e9QjTA0wa0s6UvLPTnu4cw',
#  'SXbezCVeHdTMywIUA0pyAA',
#  'YDZRlB762hEebm2OyZISiQ',
#  'vRltDI3WRnjBumYzRwJVAg',
#  '1DjtSWDLN16UTffEEu9V8A',
#  'xl5_NW2JBleYameeEIocFQ',
#  'U4H4vWjfmhFBC9vzH1HH9A',
#  'O3BVb5A0djGMi8jAfr0-Lg',
#  'hae-WXjM1ziBKfQhSP0Eqw',
#  '-0KMvRFwDWdVBeTpT11iHw',
#  'GZlJDJhDlIy-Xj7ckfyJuw',
#  'GQAvKHDfuBws7312iIqX6Q',
#  'Tnia3DIsEgc8nVPNnTRj7Q',
#  'wQMw6kc24uUQqqUGxe3Ztg',
#  'MxXo4qc5lXAbis-umS_2pw',
#  'jyWnalvlMFz5pZPXN9CRpA',
#  'F2CdVtudYJlSgTAqWDX8gA',
#  'lq0ZTMUWe_gRVomeyJxjEA',
#  '8qNOI6Q1-rJrvWWD5Btz6w',
#  '_VbFQBRa1qus4u9uaTCAHA',
#  'yaGbqAboFEo-ThynBkd-eQ',
#  'PS6MUV_adG5JH3SZ4e_sCQ',
#  'vX_U2YZV_jCK6Nj3352A4Q',
#  '8YjfILsV0xu84t0aTiceig',
#  'Gdv3qhsDeQzZ2Ag-Tzq6vA',
#  'JzOp695tclcNCNMuBl7oxA',
#  'BqsIt1BQKzS-hEKLYzBm7g',
#  '53-Y3Jw20QV6TeDkRjSyJQ',
#  'G5rqI8RjYa5Jkoo1lYbdPw',
#  'zBsAx28cbiUgqWGjKOGucA',
#  '4Z6bb_d5xgnJ5HrkaIvsqA',
#  'uarJTrBc8VsXlZm9qlQVAw',
#  'X02YNLa3Iofzwv5Le6QeYQ',
#  '26glw99QI6pf5qEq7P1wdA',
#  'OxkW1Eco5R6l-krtkEhwhQ',
#  'SgwMaS67XFl8OWgm_Rkyzg',
#  'OSqxmZQ3YoDm17KWXEKgew',
#  'oh6vICNxlLnGoyF11-a-Ow',
#  'PJgNZN4UYLxP47cy_1c-DQ',
#  'kg3uIje3mTOiEth34AgYCg',
#  'wonQ-ZsUKzCMF9Er3uGF8A',
#  'LH8S1sUwxg2_TotePOFLvg',
#  'a3ZqjElMgAe924sbXZVcvA',
#  'qEg0K_45TBlzHMOR9GC4Pg',
#  '6Th0vVjtlAlTE0cu-xrCng',
#  'PxTKXsdYqoFHWAG2amz0XQ',
#  'eigkQ_PuRON8Se265NqQDQ',
#  '_4n7K_UdRSEMw4vJdsU9jQ',
#  'IaUx8KmmqY2Z-58d_E0_mg',
#  '-jKhfsXol4FxbRjK8aUsLA',
#  'P1Bi0K_WxdGwg9pn34UPTA',
#  'FZDcm4f7aOvYK7aD7aBtvA',
#  'SgSVJWgMwFteYyz4OlHu9Q',
#  '6nB9E2ObWNjTRhrUj8dq7w',
#  'qTqcTq-ecNNml97r3L13pg',
#  'NKRFdM_LW1Nyhit_lMq4pg',
#  'invcm-tJDiT_tbUcn4C-lQ',
#  'b7XTyK_z8Nsl-uds_l6imQ',
#  'kEIwUXCl5JhbF4gzuMd3qw',
#  'SmrlGRspj2M3g8P9h-ulBw',
#  '_IsXInoow06L5C7fQgg9ww',
#  '0hDOAi_4jE6FBw2ZL_jMsg',
#  'XkzxCrgCVXAfOJB1Ks7LCg',
#  'cs1qJvnWUg_f8g020z_3PQ',
#  'GQ3Ttp1oHVrORaM84cZTfw',
#  'ZS9Q0gLz8GvuQCkPzJuzxg',
#  'VR7vnIP0rg1teDUVp6L0qA',
#  'ZvPXOQrF1N-cUd4H_p9hqA',
#  'gtfLQysuCBEAQk3wwWxwTg',
#  'PSDpvQJXABP4i-MP7mP4-Q',
#  'sF7md_NdYUzXLl5ZtwwC4g',
#  'z9SkYzD6RkmsdDw1qq3uXA',
#  'EX9sfVt9AZclkmZWayIamw',
#  '1Z9rGyR3Ld2mtnOTE4pNcg',
#  'wY8EmrjhokXEgSeCOJwoqQ',
#  'Kg_BVi5x9MIbOdbu1kWOKA',
#  'ZI6CBpptCb1Nw-udZ8wonw',
#  'ZBHXfX3vK-ck52UBEofV2w',
#  'RLLROsucXi6-E2k2Ty-Oag',
#  'y4jOgvovJ8JX3yRSzu7yUg',
#  '7NucoWCjPzZyRPjsVR28xQ',
#  '7tiobQOY3WLYYJl4uMEfrQ',
#  'Oum8ZRK1ch6jZlf0R09HcA',
#  'mq0V3VURCEA4mfEhPi6FZw',
#  'ALp--wAIVL4qQfCANn3ffw',
#  'nCIcVDlT2K5TBRFkAUlhDA',
#  'fweCYi8FmbJXHCqLnwuk8w',
#  'hkYRgPoWUQXJ8iHXSqvFZA',
#  'sqDrI3mBAuvaZcUK6vm0Fw',
#  'ehCFJyvrw-1_UUwoVV4L8g',
#  'Qf7x_9ATlcm-thjdxOWJ4A',
#  'l7A73zaNzDyWJJ0ixc2ymw',
#  '8wSccCMGNpx2j6yGVraE8g',
#  'n5S6BuEvl96RgCTafnYkvg',
#  'vXMxFqJWhL_T3vFQI2HEVg',
#  'FLJdtRvqReuvJfEb4nZVBw',
#  'o4lQfS_CR3Rrjt8UYUwdDg',
#  'qpppifR3XyADgG6tormTrg',
#  'LtPnsCPkCb41VG5fQr18IQ',
#  '5FAY_DhlgvNyUABqAgZZIQ',
#  'MwDZA24iThGtwgVMkVD-Ow',
#  'gpaJYV8IT-oT9wOt16BlSw',
#  'Ew9YPQV9g4a-L8NjigV0NQ',
#  'Szi29P4JjNiHUgEdaJD77w',
#  'n_a-dQ0mzMxTvP7V8vvTWw',
#  'zxfb_EWIjK2rzkSRIboTMA',
#  'iSByjfvaaAkZkHdki8T3Tw',
#  'M3tCYlgvLLbQfU0ybHiing',
#  '0Lqwt0DER_Wjzh-t1ihwXw',
#  '4cgzrosBI5IjwG3S5aMvIw',
#  'V7skTuBhSs4v56V54s8ilg',
#  'z_rVJjsUZ8yKvSvPLrGkzA',
#  '39lLJK_rrYY2NYomSsQdUA',
#  '30TxDt2V8G7FWXsKaEKA9A',
#  'Epbz99DxchTtP2Fpb4Kf-g',
#  'LHrfnMF1_jECj5N7YVUB_Q',
#  'dchNeTQHfK4wP45gYkrJqw',
#  'SvkZohb7zezIqef6oE14rA',
#  'ZNgtvtGm3geLUEiLsWR9NQ',
#  'cJF_93-5f5IflEFTlN4Viw',
#  'nyas2dfdi599-Ej_uggd9g',
#  'bPq5Hu-kNhzUVE6H_vywyg',
#  '45wDLpgW2BFrCRqlf19Efg',
#  'P_Zla7w2TUSraxEewSoOzw',
#  'iiOpaR1Am7svS0SF_eBoOQ',
#  'b9twNz1ZacfBIiYFrOoPuw',
#  'U_1uPKky-ocxGBvLpkMFOQ',
#  'Ea4ODC2cfqAbDbb_sYdPZQ',
#  '9uyPRXK7NGVXpMKpbOhw0A',
#  'G3rk0dDROzpDdTugsnSDTw',
#  'Ve6bA_jf9A7EWKXeyWf7PA',
#  'm2R3fjLag8EzYPAeIXdC7g',
#  'v8qw502wtQEGpQfMhCVW9w',
#  'NFHlMOEyVsbqY_VQNJFafQ',
#  'q3uuXi_U-Jqxsk5Nx1Iomw',
#  'DocFK1OhrUqnoBMVZA3PHA',
#  '-sCaUNqEfFOYwtu8WCw5Wg',
#  'QWRieSmElMDJ9ENGG0JDuA',
#  '3y4EXDwGbs7bir6yBfgPGg',
#  'zTqG5kphUBoFEApnPqeGjA',
#  '5degU5AQKGHWFu48X4JXWg',
#  'G7Lr3ML_16qrZja631R3Tg',
#  '1mJHjc4Btj2RejTt0-8FEA',
#  'OyiOg9GYKzHI19EbnWqL8A',
#  '_qA2HPqgLiBc-M4wRyml0g',
#  '_bDy-L6f148jLEzXSuBOFw',
#  'oanNWtMbtZW6gULz5nPn8A',
#  '7NhLscBs-Cj2DfPyVdGrqg',
#  'lCl_-LHbb5QTSvac-HQHEw',
#  'j9Z3c0OVhpv8ZDntMBEsiQ',
#  'x7CKTMiFrfGA1yCpe8_xQQ',
#  'PnSOaN7kg6S9fFHX9RCtMA',
#  'yNF9FqGJIJGqKmQfYALr_Q',
#  'DprO2_-TACRiPiimbtXvVA',
#  'XOKeMAuRsVkZARAnv2k7Aw',
#  'SdEeTEv3tgXN-d_c4nhBNw',
#  'zbR9fpCATDYbVdWn87Z2_Q',
#  '4aKSBiaC43EwDr7gPg1CKA',
#  'Pnw5K6dsMh6Zn_q2qcpnnA',
#  '90eu_fBWXfcRehAJVfsOIg',
#  'rtj550X5w4tDWcTE8oAgew',
#  'Ki8seQY5mtXc36xjoMfeDA',
#  'D1E_6MBFKeU2a7EQ4IwoEQ',
#  'LTpv1IAniQ8QICHrIEwntQ',
#  'BrMqGmsqIqa_Qjyk4EiFGA',
#  '4LXZzgsrM1ZyS_-uB9Od2Q',
#  '1lujZNJqP5s966L0PRmRrg',
#  'T5CdfrZWw-uW9Y5L_sddqQ',
#  '01xTdrNUuTOAyH7NaRWcUA',
#  'dWJ7fG8Egp3Ips6j0T7Unw',
#  'ifS_MYR01fLB0aRw0AQy5Q',
#  'g_5Vc87LzE40nfhFpMOrtA',
#  'jV1bWfnXOxMN1qnQXWzWsQ',
#  'lAR6Lj6-zBxQNqflZt0zTQ',
#  'p7Y09Xv3wDUyROO00UhzNQ',
#  'c33m1IMz1N7S1-sqTbsqRA',
#  '77FYW55qBiRAMZRxdIKApA',
#  'rGJt5LSMUuaMufNuXcyb_A',
#  'VzoG2RBMhIggwDtQcu8HhA',
#  'nK4PaQEpSXW6-2F_hID6pg',
#  '-S_Ln95liXJAccWi7ItUGw',
#  'cDIVM9ho73XXpVFzRNcLIw',
#  '4xXRvBVTONoGl0UrPwqN9g',
#  '9QnlJICgw57Xl1r7ZBKUWQ',
#  'vhKUBKcOm8zOLxeS3XM9iA',
#  'Q0y1SHlhG4mzUWWDIW7NFg',
#  'gMIv3zFaNW3Av9jutMrUdQ',
#  'GoWNE6T23FNqSG0njOtiig',
#  'igU-mCXzyn-gmwSzJgeMEQ',
#  'KLEq6wOySURxlZtgl88Ztg',
#  'mXW6liskyzz5udQ9vxYRWw',
#  'zY6f_cFY8HTI3hLlJj3SOg',
#  'zaDZo74bWzds9MunE6XVxA',
#  'cUykVQ_VHEzwfU53cFvxhA',
#  'e1q9kpu9wzyFHLkKegf49w',
#  'U57wwW8EcfVPpEiEhJyUJg',
#  'O5jWRmilHqaW54ChJh1oFg',
#  'cfMqHwJc4qgdIL6oew9EJQ',
#  '4gPnMySEGgUAslBGYsJm5w',
#  '3akSOcI-uzHOwGQeZD3NHg',
#  'x4aHNNo1osWNCB75q_PijQ',
#  'B6nhGEqt6rzXw6TwltTspA',
#  'jIlk4NUkoShYJVqA0edEpA',
#  'j_PL_u4SWW1LoEd2dCu0Iw',
#  'f4Fwv8ClqR35p5chZWKSLQ',
#  'zA14mz0OFhQeSfqxpZpCqw',
#  '4EFHLt7UwpX1lzmrD9FtvQ',
#  'ZL6BK8wweb-8ncJ7kFIG-A',
#  'm5sGdODCWYVu-bjvqG_OOA',
#  'yysM4mgm-xu40msmh3dHUw',
#  '8dSIAoz_UphMGpZr_uMing',
#  'ytYtMuk0URV6tk9m0zhDoA',
#  'dUffgo9Lh_Vk9TLuFR5ywg',
#  'QWrSZtFD8vRVeXZjInRZ9A',
#  'hxedolqDRVlKA_iOoI09Ng',
#  'mDiFWhywAziq9SKnj6am_Q',
#  'sZ3AWH6WPq38fEKijvl9vA',
#  'SD54jcttbv8l1WJbOUXXQQ',
#  'x0WXXrdRLk37cDPjL6ZWSA',
#  'jx7Feeu-pEMHjwdmgBcdHg',
#  '1KGLQ6Sxji5jqsQnsC6fdQ',
#  'GQkCw7318u55O1JSCZL1Uw',
#  'vJOwJQF4sDqBbecUK4cVRg',
#  'u260lO92ctL6YAhJQnLDOA',
#  'Oi2k3en1Ip-D0n_jfGbvIQ',
#  'Zf_4RPtcZ2fXgGkuyDsRTQ',
#  '_MYiaf3rKlN7WrAgC4PEUg',
#  'XhGzZwUUMEblTqwlz875Cw',
#  '1Ok2EXqdH-R0sy-_tyOrMg',
#  'lIPptRQHLs_yBT_m4B9D2w',
#  '6L7tz50A8rQBBQzn8T-wwQ',
#  'q_IrYzYP89MUq-18oedTJg',
#  'fiRbomFAAtfTYOTTtnDUcA',
#  'luJ2N0iMnfmqmj4ksl58HA',
#  'hJVC-v5GGR8SWs0Stgro3w',
#  'K7QRkS7HZDEDMkndYf0OSQ',
#  'GhrZxpoetry_48cvS34Nlw',
#  'DcdjPu2wFoMp-G3K7PnYqQ',
#  'cHW1qOB2cSXZrJDqBAOiCw',
#  'ONeWWLO5lUiyTr3roQxN_Q',
#  'hTymgMW2hA4TW1nzV9NW2Q',
#  '0h5yI6np7weAVH0jsjHqPw',
#  'b7XyTWOSchKkjhZQk13sDw',
#  'drRQFkC9yRXXZUhktaMplA',
#  '2Mp53KxlGeZJkodTuqpVow',
#  'bFJ7deZsWKgFF1oyPIDP6A',
#  'dxFttMFR4eVlZ2b5s6yAjQ',
#  '1RgX-EAQrGoPMvy9ntEXsw',
#  'jrWegacxD7lD1Cp-Kc5m2w',
#  'SiKTElhCaJGhAdySd7JSHA',
#  'soIfkcfwujR-Na1lprr-XA',
#  'ppT0Rbx0-_W0W8DqY2fPiA',
#  'L2djnd9r9-WDPG7JKmdLfA',
#  '5pMNyj77S1P3rrT69y1pkQ',
#  '04YqYgoW2ZztLpxmhEJ43Q',
#  'uEtEwSbkuuH4EurtF7qLaA',
#  'EB2dsz1v7px2C_dFXOV3ew',
#  'mmTUGqCoZ28CAHNmY-ZTwg',
#  'ZTgclQiedMle5k9Fy-aOoQ',
#  '9-yRTZGbhNwvDhxRKqZmtQ',
#  'd_2RXhJPfoZZB4Oq_25g6w',
#  'oXFRaSgcT9GwCWfC9lf8dg',
#  'IdaI8orCy7pyu5mzEHaCVA',
#  '77N_IPeA6Cb70_5m6SwhHQ',
#  'smmIWAEU9fbJbCCiJHT-xw',
#  '4s-eHLQcoMqAgfzbiQsKIw',
#  '8mpIro7yAzGIlFZ4oVowBA',
#  '1GulRRJaDG5SD5DfITqg-w',
#  'BzqwAx_KlRPAMGXw1xHXag',
#  'ijjuLKQ-h2esqrF7vnG-bw',
#  'lPQh_HUXRtxDQeR9WSfMZA',
#  '-z9IQza32guuRyqF8jxMyQ',
#  'OXrFWgoz533T8tMRemkiww',
#  'Gm---0O1y_4TAQAl5qKvqQ',
#  'xoA1_vsxC0xD_fPgDZ2mbg',
#  'K7wkgmHe4q5vvwVIIbcleQ',
#  'exysqt4RqxkF9I8Z2NEUsQ',
#  'r-r-aHrFKEXGcvDoBolWvg',
#  'AjJMzRFJjORg-TrpR4DIGQ',
#  'QnlSgDRrKzuZqe5VJzvBCw',
#  'ZyHdmeEnucnlMlK2Yk8fUQ',
#  'pMtNPlmtyPGcSlqZOHBJvQ',
#  'VmSkQsAjUtzJeliKeGQCOQ',
#  'wRenOtfZOOwBH57U01Ipnw',
#  'O1P4x0RgJWb6WaetkNqfEA',
#  '9GA2gmLV4NX2oJkuz6fdcA',
#  'M9uciMmlGmp79AP3xW9rTw',
#  'gErcz2Kqc-7E6b_JuU1VKg',
#  'Uv7dO93lwpq0MqGsu6-_XQ',
#  'hV9XufCpXMn2eOHzKZshHQ',
#  'WI3wXk5U9wiBpeVqU1N9DA',
#  'KqSWho4bavZzNH0qQ5GnQA',
#  '--GM_ORV2cYS-h38DSaCLw',
#  't43XJ7we7RugvqM5ytr_WQ',
#  'NuT1ejKruFnBFQWC6Xg82w',
#  '_8I19IRzDXmMSRES9cEGlw',
#  'HWMvxmKDrHtmmcsOmKA8Yg',
#  'zc0sUY7iWuJB93AHWKy_xw',
#  'pGu7YwnkIueer-3r3pkQdg',
#  '5-Z7VmiTqD4ycnrxfBJGmQ',
#  'F56TiSa71Tk4PIQ0HN8oag',
#  'e3QhVshZfZYCF1fEhwu5Cw',
#  'WvunDFSs2hJrPHVFqB6Y1w',
#  'RUS5xdYjwstuNkKO8honsg',
#  'hZuRyS8IXXuEQkUCas9O1Q',
#  'VI_8Wsx9ox4KeIrERgQyrA',
#  'l2KV-9-dkrvhZF6lNrPpCw',
#  'BLGo7Hnn6080YJHJAtifOw',
#  '4aAf2nAr86lcDHzqWSaYuQ',
#  '8v1nk5EcCyEKK61ohAh5Og',
#  'zuV8bmrmf6fk5ZeQJo9iEg',
#  'fB8ri0_dhcezdeTVYdRGkw',
#  '12QSMgWotDC56qWxAjTdDg',
#  'Nc7-nyG_RzXrEqBuxihcgQ',
#  '2kWrSFkIes_d2BMg4YrRtA',
#  's4fNTcuW6DGfiAagPMlQgw',
#  'odJzhCY4-FqEvB82sNjNsg',
#  'toYzcHwL9ueu1cPfjnAL9A',
#  '81mlHKogQMh8E6f0r6AYTQ',
#  'gISF0NrCpXT4m19a6WxvlA',
#  '9h1yt59R6N_dpWSCA1FDDA',
#  'qq2k2tohpim0gStdb9vCBw',
#  'HSoKTWnsu7f3yvywWvBQ4w',
#  'FhVYpbvE8IQeUHAcwPPIXg',
#  'fxZOOJtT6Zau7Asmppigkg',
#  'ftpqfo5lrnCSLv4UQ2x9oA',
#  'V2_MoJphE47wYFazVF1cSQ',
#  'smdGDx5PS2Nt67FXYAQSUA',
#  'yZE8Vwam62qWB5bO0kvp6w',
#  'XjsCGzq5P1pCiAHotA9HCw',
#  'Xp6ogw-SCNK28s1I0fhUXw',
#  'O54jXbKjZte4qVYabYjGjg',
#  '41lQvgIQEfEmqINKciNGxg',
#  'Tv3YzCxzf-JWQAiXNkUrMQ',
#  'HJBN-TfKtjLFY__DmuEovg',
#  'KZp4sxZR1qmDZvFqVO46DQ',
#  'RRUyGOb4MDlPLNHIq9gMRg',
#  'xYJGge9wPXNb_VpDyPh4Fw',
#  'CJ-g-itpZaUAeQ79j_Z2hg',
#  'ERnG-1q3igX3VSgm5uLZ6A',
#  'rBU_G1wrSoiylPYj19HDNA',
#  'fkxDuUBMc9G7lCrk6nWeVg',
#  'LVKaVJMW2VGu3OoFXU7Xng',
#  'u_8cVZyxh0J468zEZUjNDQ',
#  'Tn8m9mW22K5l1Kuf1mv9jg',
#  'TqFqZBdad2N0Kgf-NRKL9g',
#  'X9WJuPwL1-k1VzExlGXdTg',
#  'KtSEqZbGV1WHgOgtSMEZFQ',
#  'LLGCa1g8owtW7xa0BbKDug',
#  'SKpg4zgr83YPZ14uzhmn9g',
#  'gIOpptgl57KGrOAFw_ViIw',
#  'OilKQPdBj3rD7eZDF5OENQ',
#  'G7quYX-m8oly7we9A1JZ_Q',
#  'Ibd9jfvPecU18-7ocb-1yA',
#  'OZVjQy15DdNsSW3bRAL4mw',
#  '_9oVB-ICuyxfnK8JGpiwKA',
#  'tovUJgSCxi2JfUtP9eNQcA',
#  'qtsrM6Xxh1LqxG0X6K6tuQ',
#  'WiU6fACNR6uUAC_6X5z-SQ',
#  'TwYdL1qY7FFBl1BqCo-CJw',
#  '5x0yRV0ds9IN1ZIlo3XJ6g',
#  'sH9aI3xg-POBMp8R-kSQZg',
#  'DiUgFZkt88xcDWG0OjjCaQ',
#  'mJ0CA86roChYwaDkDxFGwg',
#  'Qm2datcYBPXrPATVGFJQfQ',
#  'e3gLd-8XXC_HnvcWtjnrKQ',
#  'Do24u1eUUsn-BzqXwzHUfg',
#  'SE594hJrunTVaALEy8Guzw',
#  'ai8nfTBNvL579cjIuqZajQ',
#  'cdLjMoQPRtdWN4g6LW650w',
#  'ui8KERxCwlx8B5vWvpXxqg',
#  '2_jWcWOew5DA6wR7_eH36Q',
#  'ZBJm85DMnmTCRRHD9x4Ydw',
#  'RFCtxMNwO_8ONYnWNDxYqg',
#  'mOgZ0U8hO_ot7mGRd6BFyg',
#  '3OdBW4ooaACTNugCb03Djw',
#  'LvsSh7ojoyCjNqqrl95iwg',
#  'rvZ5PwoDd7gfCQie--066w',
#  'OgM-BL1BrQ-F5d433wVUmA',
#  'abA0s0uxoeOn7zNm-1dDxw',
#  '6We2O5X62J_gduXU7jvf8w',
#  'H97gae0HLwN876RhZ2q3Ng',
#  'AShjimfb4-Acstqtg9OYrg',
#  'AYL_y8ahquUW0o-cvIyLbg',
#  'avetnjFJc5Z3o_n7czQZhQ',
#  'vQXhuCQ4Wc3WWesp9hy3VQ',
#  'qGPwz8IPEQZWlBgVSTUqHw',
#  'gGS9Os0UBBO8BosD3VnwqQ',
#  'VjaHHmV-rSkFaOAnU3faxg',
#  'WQ7Qys-keM0MCO7IGpEduQ',
#  '5CJOaZc8Muu8WothauxQ4g',
#  'SJxm96AkOPhXZFRM5-RbTA',
#  'aYGqrw1lJHs8Hw0kHC5TVA',
#  '-8AoSGOdZyDdTpT2oqX3zQ',
#  'sCpa9e3HOSPuOlZUIVTWKQ',
#  'EOo2My0Wt-h942RbNRzEFQ',
#  'LDIl863KlzNr8hmBXupkdg',
#  'o-FOHyhRfysM5-4HDErP2g',
#  'hG7GPagUoqCHLowKzlR3kA',
#  '4-xLjGavuWFqEfNuznxL3A',
#  'soPUpwqle3vkM1gl8Fel6w',
#  'ouehYUlrMzvA3aHclsi_zw',
#  'QKYGmGpwde1aM8AxIGNaRw',
#  'ROZCc1XMuAJpyhvTxotQ6w',
#  '_OAtYMzu_oOf2-HGVhrHVQ',
#  'VRC7J-ahI4em9ddhihxq5w',
#  '4_Ye_9x3dyMK-cfCBZrBRg',
#  '6OpLHgun6qHmrX1JmHL4zQ',
#  'n5UMGTW2394E1Qk7guLSqg',
#  'hbGLy5j0RBiaoGWxgNsbLA',
#  'NvFpFlu-aHzUOtaA0yc-YA',
#  'HC7XYU669ZXbE1cChU5U0Q',
#  'Lkq-3a2oZUPDSUWBRzUXWg',
#  'lZvr_VDNWjCN_PT67StkKQ',
#  'jnxt9D-rkZ3j2Qg4Afux3w',
#  'Zog3PqBGy0P7WUc8cLR7hQ',
#  'qcTaluNjodgXvSE-MFYvKQ',
#  'WBay6AZsHMExtMQsRc9-bQ',
#  'zHqydarL53YWMjuC0UglSA',
#  'kWW_EvMdS87-sXadKsqtXQ',
#  'qrCWmo0o3On13ltqOdRgkw',
#  'yZweDoo2mcHxjojylN58OA',
#  'uIBNPHjj7Wupu9tDG7lQiw',
#  'SxvKjtbq5qRlFoXrU8Bo9Q',
#  'MtjwVcFHvtogmJZ7De8M9Q',
#  'dPqbKki9KBSFjxxLj_urwA',
#  'cXgXRqB40CGHEMKQgxLDTg',
#  '-fTO9qRo70bblJmbNxOnag',
#  '_JZ7hXqOZ_MngjPWFgER0w',
#  'tYbK94fl50os3h_RjpY4gw',
#  'DWaKkloU4L5zJzWV4m-6TA',
#  'jF3zUwEWluI2ZPzkke9mXA',
#  'X4rqmQMJcpY4EajFAFTSlw',
#  'uDHZW-ueJm9UxSkuNuVmtQ',
#  'tb4uP6nnel0veA_hvFmr6Q',
#  'dvw21oJvQ4cZCaK9aferpA',
#  'd-wvSnFt6JAZBzqMiGpvyQ',
#  'hVD6mqXpzhk1n0qJAdL72g',
#  'Kzo1z1hW6224lNd3al2SbQ',
#  'csxR_9zmU2jJREvLUGY2Gw',
#  'HFwNNNrPrQT3rJD1VwEjTg',
#  '1iXVBWgECa_ajaYcTINtDw',
#  'MALMIau2ZTVhW5AikFVl3w',
#  '-isxnIljKLVjc9qEhCiaGg',
#  'pxv5jBUOgsg6Rf6Z88e4mg',
#  '6sqqGMTSQTC3Ao3VZrkxRA',
#  '--U98MNlDym2cLn36BBPgQ',
#  '5cWPgytHCuPq0poBz7r5sw',
#  'Z6ezEudsHeYzqKCj9vWUww',
#  'YBaWP2r64BPJazkmyf1fig',
#  'fPRMjWUHLnNeL4xjrMV9CQ',
#  'pwXkM4yHrcojgnx2qJQt7A',
#  'OhUvHNtMiRzWLiKiaaXYBg',
#  'vbqZcwnXLdOFkZ4myfOTvw',
#  'qdc7oj5rbf8JNV9z_95ewg',
#  'e80gyXsUZ7__eAuW7JEj_A',
#  '_4zFDLCB8Ukz9JaJnzTi4g',
#  'uAVMHdO3hz35e9RbS54rQA',
#  '8lZtLSeJVg28Gb75iklmmQ',
#  '872bhARqHoDEljyEboTDew',
#  'OIrYGca3yQdxEZQR2yhj3w',
#  'at5Oj1aprhbFuqwojBIkqA',
#  'E_IIblD1Vu9YSywrvs4vBw',
#  'vROhHLGsyLh9oC9GNXJBfQ',
#  'WlArCYe6xCzOe5u2Lt1how',
#  '17eWYgtUf15qDUrk2FveRw',
#  'ttoTU2MrP0DSXtOWAWBEhg',
#  'whTqmbE6OzlJUhm_vMtKqw',
#  'ncYlaqX9pdGCrt5nAPcgUg',
#  'mlXQFMNrCFgnOjQhylD9yw',
#  'n5cOOgEe-Oik76YYhc302g',
#  'OVTY-NpcTA7iXbMQmusv3A',
#  'G1Q5xN9mYE942-0_rTsMeQ',
#  'yNp0ybYo07JQWlmdz1K4Cw',
#  'aGA_iSHm9laGTrfPLJG1yw',
#  'ckZg3KVwR9FrAR1KtTavEQ',
#  'lKIDHvxHpyhruR_J9P42wg',
#  '8RGoNUEC4QGbpF4af7CDdQ',
#  'xePC2Iu32dgHzP892OHIUw',
#  'ZJVZGDsbvUz2kqPK2nR3uA',
#  'aVNQGP7GaWscT-huq1O-Jg',
#  '-gcS8S7aiHTwYROMC5QP5A',
#  '-gBRmZwDhsooJzf1I7uPyg',
#  'n-m449doCYEPAb5ux3dmVg',
#  'S0kp9gHopOeiSLQzTY6vhw',
#  'prPOsr3aS9IStGdBil9l5A',
#  '8xIWCN6PlW8E897gFgyFeg',
#  'wKvvX7nls576gHPyzKgZ3w',
#  'aNmMmHPZnD_8WiPdAd5WqA',
#  'mGkVxLpndvodT92iRvbLyQ',
#  'VYPi0xi0k8llY3D9tcNzDw',
#  'Tz4fdGixKO3_HvOh8i81Iw',
#  'Edc4OQns2A4lqs1KT3HE-A',
#  'U7Ag9oPTjWinwcnGH20tcg',
#  'h8MMgum-XUQhU4xWCyQWLQ',
#  'W1vydY_gBcNQVsOGlkdtDA',
#  '-V3wr3C29UA-_wowT92lFw',
#  'SQUfO3XMRsN1_j5M6864fA',
#  'SQ8Tkavc4TJj-2kanEDzLg',
#  'IlEyOZ_6dUuhrDqpMN2GXw',
#  '8BAQAHKFlstlm1APdM88nw',
#  'FvXZcRB8bocNMDvFUnoWhg',
#  '5Pw4p6Ium2hhqZpkNlT2ZA',
#  'PqRfOvjPa0EqbcH4MQY7pw',
#  'jG1jcAeDw0pZTHCNC5kw_w',
#  '6SGDzb7yBIOjJS9WPnzJ4w',
#  'yY9XOQ1Baozl8HGK4mN76w',
#  'rWvn5iE53sHqRXPyzWc0TQ',
#  'XdhJ7PjfMjBmZwvKikWlkA',
#  '9D9VuQW6ysUacf63q-5pMA',
#  'sQe4CqXpC-kxu3ErbYgXkg',
#  'OTDogJk9hVcM0oT_ia_09g',
#  'Cao_8SCICexsS31lbjFBVA',
#  'SHHnB7GsNyA3y5dg-P-LMw',
#  'hwmj7f6KFvaCjhRe9MZ_Ag',
#  'wgImSrYc5LOcFaMcbOuxkg',
#  'c-XMctLK6QAy1NjLSkcLRA',
#  'oP0eUhf44jU71-I8DwKU5A',
#  'fK8RbGvHtwVwaFyhF_TgjA',
#  'z0vzCyS3qD9fBMbFSJBXJA',
#  'CJqAQwalDOVoXBKDprIPug',
#  'uuaH1UNcqcV-alT6nh42WA',
#  'dsAcgF6qtZy2m6d_yWCrGQ',
#  'mzvOKS2QFKGIMFdLusbjQg',
#  '5ZQmIhBVOelUScK9UbSUqA',
#  'ftkUQCPM-wFu55Ou-BzFgw',
#  '5gC3o2QHCTsowiVrIk7G9g',
#  'DUQxjfbYLtg5lhAJ1K94Hw',
#  'J4tO07oCDhwP3rdcgjjdxg',
#  '2wU2cdWiKegJujTliMJx0w',
#  'LVcf45xHK3RXnFnFgH4lAw',
#  'sB8x2oabQtL9wA3dPhGa6w',
#  'TwZL8gjnAJ3DXXnyu-McHw',
#  '870wJgRZMQLt9jNN8-RgQg',
#  'mUONuCWBKukMO2uyVxLY5Q',
#  'hSU3MbB9Yu8MlybxfmABeg',
#  'ym7uH6ZpCfKQ1Of7eaYGCA',
#  'AYLxEeVq8NKG2UhcBiggrA',
#  'ZUvAR3I1uhC27zQFcRXumw',
#  'o1Y1JV8khAMD3yMUZymr5g',
#  '8f5JVaK2mZCu9lct23dhtQ',
#  'a_HejZvHvG2IM7ri1CnlYA',
#  'IOxRbnv2YnLtErYY3TrU3A',
#  '47Uu-2MceSRFmohdzCOvGQ',
#  '39irKvcTTf6sj8WimdRXxQ',
#  'OlvsH2r5A82qVVP1eSDNDQ',
#  'yhT2iTPtvQttZxYS9cNF0A',
#  '88QR1e2mFNd6Gt3BI1PNpw',
#  'vkfgHfjKvR6ZlsENWExhvQ',
#  'b4RHh9w1zyuw6eqm7m5hGw',
#  'RpNJRmL8qcWQgIyvt-DDSg',
#  'ljLq8ZTLO52rzwsEeaWZKg',
#  '8P_1BfqBW4HnRYOJMUpneg',
#  't84qyV9obtgLLjfNyLSdug',
#  'v61dL5IvtgMwYBDNopvPYw',
#  '5EkgbZnCK6q5KLWl6Au04g',
#  'ALouXcCfsrnbpNEpO9-Y3A',
#  'HORILLsQHEMc5o9bIoDJMA',
#  'wkzWdo1mBqbzR2KPoXtWZw',
#  '2IHmggMLM-hDq4dFmwgzDw',
#  'MSX-vRTxCmKLNITfdGEiOw',
#  'gMONN1bKUHlNKPrYGSADLQ',
#  'DkIEhR8behaIoSexekWV0Q',
#  '6Na0jTJjX5GQY_ZJ53G02A',
#  'sfzX4Ndds39mhS-Chr2lJw',
#  '52J2qJTmfy2NWnQKiUgYBQ',
#  '_JO4bxQ9hRX-42XFMlpyKA',
#  'kzbH1_l7VTSfFFcwTqY6vA',
#  '5Da9dUZUaqR3NiTE07-9Kg',
#  'zWdO_P10pQlBKL95gYC_iw',
#  'T0ju0drMLfXJPNLnEsEYgw',
#  '8vnQAJ3zzI-iX_d0SI7BUA',
#  'BNLFEPZTyhNObVzXsTT0iw',
#  '8dSKEPQn0pmZEmWTKZI81Q',
#  'abIpel3j-MAAW4EzsRRl9w',
#  'ID-awJIobDBZ_cqDjG8irQ',
#  'fQKU2VCVQkMVOnPXSqyY4A',
#  '3QzPhQ3ltbon0-1gC7Q18Q',
#  'a2aIe4d-d7wUtkWsnIiEVQ',
#  'STmBOy-RzoC0erzfKxEUxw',
#  'sxQrSzv4SS4b6o3tgmWS7A',
#  'gcYwWmzzzC4raKZ5FoTsNw',
#  'UR7_pPtTqN5kjh_QBIGYYQ',
#  'k-3nsmnnq4cnUutgOVEjaQ',
#  'yBia51pdmhCmZdnwLa-uUg',
#  'uNQFbFnQK-a68S1ktfD_yQ',
#  'muFJIZKZwbAfy_pEFKF_pw',
#  '2wCzZUwcqRRBrAtBBYxnog',
#  'HML9ElO3X20nYOX_l8mwBg',
#  '3B6BFYDzXOWwrjNnJzYksg',
#  'Jlk4tLFXusQ6yWOFffpUfA',
#  'gjATEWAllTfxfxhGqJ93sQ',
#  'KPsu_1Q9XYRKWs_ZBTtlTg',
#  'feu6_wWLD5l_2Ha3In_ENA',
#  'qisbqK1wxuwp6GumMrwB2Q',
#  'BJz2p9TJ6t9Po4TT0GeHFw',
#  'YHoDKkSvaqcmwdFQScQV8w',
#  'L0plLBAZV0CdVVg9ZM7UDg',
#  'vtSjoIuz2CeRTf_aMEPkFg',
#  'ZXqiETQpe--0ufUW9B1xCA',
#  'P9LAh1yahQqntqTlXIVPnw',
#  '_RYkQNjV_D6xOzRp3RwVOQ',
#  'FuVGP7x3pib95GGrN8irew',
#  'n_LSGXDDApdFS9EC2WGUGw',
#  '0a5jrIXBKH5aRtQzh728qg',
#  'IiqTJ9QnCZm1SUaH2CUTfw',
#  'NLQaO60U9As1MFcJ95fcJA',
#  'lCZ1pvgb9i3c2y55XalbhA',
#  '04NemZnAY0oyAHCg68x_ww',
#  'aVBFKYoF0AHuusNssaQpJA',
#  'a3hjBPsnpcTpcquQXLeS0w',
#  'QR2V_Iutb9tEoXVBYPo-Kw',
#  'UWTrl-zucRYCy_bChOtEvA',
#  '6nLuU3av6aQiLVXHNWLbew',
#  'SESxUf6mDI-Gw9AkY0Tsww',
#  'q4P3WHwC0lFafwvTlkKMIw',
#  '4cHJ1PfvCOsXRHuhzOlnLw',
#  'Hgpf5qIX9jq2E47OsIJ8cQ',
#  'VAHzYaJ5IHjhyONndhqilA',
#  'Z9wnRnSvmt7PeMo69x3s4A',
#  'm9tH7h2sKkyWMdTbBYej9g',
#  '4NkEWTs76FplOihc-qyBZQ',
#  'XIvOboURyF-hE3truQjdqQ',
#  'EKCSvhzoAWHjAlD2Nzj5zg',
#  'ppwYJPfE0tpSJA9X8l54cQ',
#  'X3-ZauIT8o2tcoBHjYUKFw',
#  'Oe6cb42EkFvIWwEIooY-OQ',
#  'QnZ7YUoAJNP99oFkS9IpXw',
#  'AWL3aobRhxf45LPe_5BEqA',
#  'me17NOULVwu40AdKGYHIaQ',
#  'dkJb9ustnZNogY4QDvjaYw',
#  '32RDYS1pxMytL1rBSF__UA',
#  'HerosKATot0-_0d-8u-5kQ',
#  'nFoMd8PfQ4KbOYxoeTxK7A',
#  'O5vXNIody0SMddowzrAMXQ',
#  'SspR8JrDvf4OAa5aOq7I_g',
#  'adJc9AzAa-kM7PJFulokQQ',
#  'YsxyAYrg2LdMvf7nhp39Ow',
#  'mpu9vXwm57D3IKuLn13zjA',
#  'MJpn_jUivKSgTtjNon63hA',
#  'IGYlCWnhjTg8QHvnaxpagA',
#  'TEXUVhF-G_v2Sxwqti8HQA',
#  'xZeMt4Vg-P9PTyLgCe5phg',
#  'fiFNpXVk4OkW76vzDtL7JQ',
#  'uEqkWCzfywBb8hCHhTquIA',
#  'VsHhy9ixEze-AxNYt6UxLA',
#  'RH6GHFdAS-uj7nBDFjsBoQ',
#  'FdiZDOs8LbSnBpA_e5R5HQ',
#  '9CcOOIJckoGF2sA9Rw2ZSg',
#  'oTm5qUyP6dRWnpW9IsAgFQ',
#  'k3Rgx5dG5pj1c3hbuniQ1g',
#  'hrrPxT846kLGs7ehEtLmRg',
#  'T9XOUa2dX4conDOqjUtmhA',
#  'VNGSuR68Pxn2Te0DMO6Xmg',
#  'OIdOJaNS8M624F58XGV3PQ',
#  'vScAfR-mKEWn3QTGrbpVjw',
#  'u_ZGUzNkGppD0-WR61bd1A',
#  'tvUhTJcZ0R0TrP8AwuwSkQ',
#  'Da0c8BkSx0gxk5HwoZJiYQ',
#  '-eKBtn0mPgcWqZ89jPhLeA',
#  'TEvCRTMnOYwQ9Up9lWXxfA',
#  'lK_iVjCur58if_XcbENGqg',
#  'uRbuizm1j_9gTRMJJaev0w',
#  'A-KOfbVxAcpfIq0u9kTM9A',
#  'dDW4Ou_cT1aBMA5JcRuCSQ',
#  '9fH0ow907crGLmPnHFeI0A',
#  '9bxcpud3GREFOxKY2cbheA',
#  '1WsXLCPRP2EZ9KoBRTkSbw',
#  'sH0IBENjMdWMEjqEfep0Qw',
#  '7FKvhOx2iZbz86T3aOhB2w',
#  'tWNdXuz8wBbyEFllemjrzw',
#  'EEUUONGguo8POLMxmHZ4UA',
#  'vSXum5CZEgnouVyPo5BTWA',
#  'Bpjhk4ZtncUnntdqurIrfQ',
#  'FlSz_R7LkZE-eqNDuQ_CjQ',
#  'w4y-Sx_PJpP6sCfK7obuRQ',
#  '5jWBMCoR8aAXBM9RNyzzbw',
#  'WxHgUs1JDtubttO3MkQR_Q',
#  'nOkSC1GtMUJ_I70sb0SaeQ',
#  'HWJCPFVFBoQ4-kBT7blJUQ',
#  '2KIlQsIHwYMkuwA0T4OKrw',
#  'KbY0_47p3n7D4SSFGMxw0Q',
#  'Ykg-jzdJS5UAlkF5YaCsyA',
#  'v2UKNMDqWN1UaWlK2Ugx2Q',
#  'QZwVC3LsKDK-37iF6-X7hg',
#  'Nt0ILbydRyDbE3BPRZCrew',
#  'WexmqiCQfCMrlRbMjCZx0w',
#  'Dnq4w6ajMifZFFTIR5cGxw',
#  'a4I6hTqQwL3Px1aXfHD4Aw',
#  'EkOqxlglUpw9YUdnTbbJKg',
#  'R2hVz1386VvoPFLdUbJyDQ',
#  'szeG61Jn4dFrLqhZy0m_ug',
#  'IoPSrK19Xd9FG_Q0x_CcLQ',
#  'n9PgccTPsLxgYL6ZCkxDMQ',
#  '-ZaQKvtRGQA-4FoUE_1s4w',
#  'zgtgMlvFk5Ilrs1yj78tdA',
#  'txF4WKY3P2hF3i6VCRD8YA',
#  'lU5SyqwRlKS7cNj2DrCpGA',
#  'AHAfH6maSPcVPJWc08dxgw',
#  '5OO2qsLunRpdyEoQkBrfgQ',
#  'D9unP0Qn78z5HkaeT4_PTA',
#  'lAHMg3pbNUqkHbvclEZ0Zg',
#  'VqF6Uky7SGfjWitgxrhlJA',
#  'nc6vYPFSWZV6NbPAOEDDpA',
#  'yung5GumwW7s_-2hDz476A',
#  '7f2lYQac9MOZDSaQbMs-Vw',
#  'soLU5qCw1otTHge9J2MQ1A',
#  'gITBefKO65DKNcCFQp424A',
#  'd-PQrWHCEbv_lH-UMD874Q',
#  '2hgfYu-jBRUGybzl_CvqvA',
#  '4asr35mgBPLpNH4NCFPEhg',
#  'mV6lTLYdIjPcyFKugQq1Zw',
#  '9q_O836mXia6Lqkirl2Ynw',
#  'HrXrd_S6cDbSjpsRxIGsog',
#  'o_PJyAnngdzxpC5WDyqtyA',
#  'h98IJqWW0wVxwoLV03Azfw',
#  'aWndhjjBzYgk5OOYflbK4A',
#  'U9HhVS9rtYAYh4ZVcWWIbg',
#  'xrpZFPRMf5WVgVXT5uuJ6Q',
#  '8idRgzKzCZ2l2_d7nUSQDQ',
#  'rwKqYbWkseELVVSAZ3ogpA',
#  'SWhHaWFuijy_KDs0zVCJog',
#  'x4cCFdLMKOudfIyxOMtUJA',
#  'hrNIDao4XnOhrv7aaFehTg',
#  'GarQqqVFnqe5DjKK0JL9sQ',
#  'aidcfUzZLOjWgwlxfv3UlA',
#  'MkITdtEYh1ocu7uCJ9R4cA',
#  'jBhRphJtQahNTWwFt7wlrQ',
#  '2NiBvT5zL272IRcxru_x9A',
#  'dJll6hGkOCFztZgFKBTUEA',
#  'AYle9bIhjpA-Sk94N8W7VA',
#  'sou8ZMPc7VYMCVJ-kGiRJw',
#  'd553fPaVCGY6qjap-Zrf7w',
#  'JxUe37ZhYlfi5_0hUaJ_oQ',
#  '4z4vQVymdvX696SI0w2k3A',
#  'WSOFs-EA7vhT4JoHDJz4ew',
#  'UE3owaCu9En1RD7jTR041Q',
#  'BSmqxPbQglQwP2R56OqOag',
#  'VDGMgPcGFB6acVw1qEoooA',
#  'hzmiO1S-P7BZxtEDK8e9Mg',
#  'XNudJHO9xBElglTwqzhh_Q',
#  'k775kVhtbiiXyOtUwYruUA',
#  '7JSOssAyZ83aYgohoTUc8w',
#  'QCZwZLYHkTyYQDr6jdjKjA',
#  '2ZZmVT4Y8Rk3OIzu18PvFQ',
#  'fMdnlYyN5EMhafyE3dGTFQ',
#  'RNO7SRmfVi0CyXjtPhXELg',
#  'wuyJfCF5gWyz9yrFMaGczQ',
#  '6rl2DTYflL0t1_oL4KudYw',
#  'MJoHqF2VIKhBuMzpRnwrZA',
#  '0oGbljgcsv9OGgjYiX6Tbw',
#  'lkHSRUAv1Jv-U4F8ayzk0A',
#  'Iabd_rGdOvdpySBeluFs5w',
#  'bY6cylV5ASHvD-gCuKTptQ',
#  'tIG4CthhLdIim_qw4fvhxw',
#  'bD46Yt0A_zToPPPE3Lv1cw',
#  'nbboPcIPAvVmRXVeBeBDkw',
#  '0rjaTy1d0bRxmaJ7HAPYRA',
#  '-WCGJuDoq4yAm58DQpl14Q',
#  'XPgurhZwZgNAwHcrpoe3Zg',
#  'ZYof0WYlilJ3pgWNSgmYKQ',
#  'MLi1IBqDaVQuONeuXMMSLw',
#  'WSm_DwJ8LJISkpfS9EcPDw',
#  'oS2kWKUxGCjy4EH4QCa79Q',
#  'E4t43bnsfeOY2bv_8IPmSw',
#  'Z890syqhhoShqFnIyIu9EA',
#  '3Fr9RZ8Hfz1iWk51C2RMWg',
#  'o7io7ITyHfjXOpxIktL0Bg',
#  '8dNuvBvySG2FxFdEwAOKeQ',
#  'b0WztBYRaswkUARxLQ1aKg',
#  'QtNvhMHwbSrrRtaOwXeYJA',
#  'VYOtofDcgJIV5-vPUd4sZA',
#  '2jau7OtoplE60-o2TIn6Tg',
#  'knzoe3kCaoh4gkGwA3l6Aw',
#  'SX5NA-yKCGR234vV1eaxZA',
#  'GtRFZornDaDFpp1DwOgN4Q',
#  'Il-H2pDli8lBrurPG3YbFA',
#  'OOaiDUh2zF3OmmzUeXKiGA',
#  'bcYfyI515Ji9RcMecDCl5A',
#  'jO9gbncmBCExL_FvFKU5Ew',
#  'ygwsGEBvQ8Tj2xn4FCQQXQ',
#  '_M5ngf01IBY-v5LhluT-9w',
#  'VVbp-2Bs5_MGrjboTwpSRA',
#  'xXxg8CBBdt8P1VHmUl3v3g',
#  '3slaRoID3wWUGcYaSE8EuA',
#  'llCxryWr8j1S39tusYCWxg',
#  '2og7CivCoU54PKpvlvxOYw',
#  '5ThWWKOHkBcSV-EnLHQ9Mg',
#  'GO6HVcOtwuIOSzys6Qut9w',
#  'VDcBThHQHE8dTFdoghQwFA',
#  '41qbd6aGiz2GWp7TI8HSEg',
#  'B2SPDI-2ESi9gS7fExW4aQ',
#  '6--gCQ9zYrIMW-VsOM7XdQ',
#  'k2b3niokS_tosjah_rzCPw',
#  'Mh84_j7YmRrAcm0DWV4bUw',
#  'Hzp7oS3dhpFNNBd8yDmqeA',
#  'G1t9MT6-sJvrsG-RWLgCkg',
#  'v_ubyYwllvUW1No-hKhsbQ',
#  'L53Ye3HxRCT_8CYaWv61Aw',
#  'bG8OeTrW5T7pRaDgKKUNAQ',
#  'HRIUU2Z4EsZBo59P0I2ZYA',
#  'JBivZu1L1VpYf6kwspXYIg',
#  'P87jyPn6MkeO-zo3EZWL8A',
#  'D6SCh4BwNb52wZIqXdS4JQ',
#  'Hqs4YNST_ZHbshwyi4bnsQ',
#  'RlPiIdIdZWZXTWfSxCKrww',
#  'sid1Wu5Z4v6yiHacGZdUeQ',
#  'pG7T6_E1kJmy56HhzsOohw',
#  'ICJC8hjJGugQyVOTmC2sGQ',
#  'cdpiHHignnk8hVcPEiYzMw',
#  'b13pUQ9-zPZtQd-9V6mFug',
#  '3nDxqHvf7L5AdEAAeMaQAg',
#  'S4dLodWFIMjDxQKxuzHi3Q',
#  'ZF5soqrk72fzZJbkHx-fpA',
#  'sbMWVy6V5olsfLejXwgX-w',
#  'y1esDY2vFyaTMf1YlRT7ZA',
#  'pBFewLcdLnf1XwPTE4jtyQ',
#  'dUkyIdP5j4vPE0uFnDfaWg',
#  'OacH3fpQxtfk7NU-s-Rmmw',
#  'MkzaB1merlsrz92EMGQQkw',
#  'iDFEPRY1qr4iYznekkApGQ',
#  '3S1MilqTzANgLlJj1oQw2Q',
#  'cPWbolWE6ip5SupmfH-nBQ',
#  '3yhdmUXeZS5j9xZRcuIv0g',
#  'ujNN29ZEn8GaipiDLOQhEw',
#  'Cpsx6c52u6AoeP-8ezH9OQ',
#  'xRHbsV3S884mE95p4-nOmQ',
#  '_GKMtL4zFOlNc0U3gljT0w',
#  'nOykFBuMLOuw3ZB2WTk50g',
#  '0mxXTe1LPXOmPy-aGhZTuw',
#  '_2O4E4qEnfSKWGnopxRxtQ',
#  'Mrh6EoDcsDWmvWBPmK7ncw',
#  'npTomO2iJwilPgn8UOQqrA',
#  'P8BE9zzM-pUuPDHs6gsy2Q',
#  'hbXM32Np33qJYmx8HUtXXw',
#  '2EqeMNnCS_TvunnH2byPmg',
#  '3QQEc5QUP-h6LCkUZQEYQw',
#  'flaAdLvjrSKIsMGKvCDO-A',
#  'FGL0dGh9450_SEtDNlU3Cg',
#  'DU2btqXJkYR1_V3ix_bb2g',
#  'OSLNYVnB69k6zO9jYzRPuA',
#  'YjmbCvygeMj9dfJp6neQ_A',
#  'JZEw18_OhSzFj0IfXF6v6Q',
#  'Cg2h2Cn_yEs06NZP-3QQtg',
#  '2O8Hq2eQ0hGFywNFJzuJqA',
#  '8N2yHM65U2Xb3YtlxijU4Q',
#  'IOEGLxXwCNiq4P-U359D7Q',
#  '9li2xKBUybR_7JGiCwo6Gg',
#  'sj9EGBYtg-k2wddhKmrAKw',
#  'ia1Q47ANt6OZDMpQPzkqJQ',
#  'jCf84-Amxm91rbNAOJtAcg',
#  ...]

# %%
#ultimately: find subset of pizza / chinese restaurants 
#set-up methods

#for a single business_id
def examine_reviews(b_id, reviews):
    '''
    concatenate a particular business's review text with the corresponding dates for time series analysis
    
    Input: specific business id, review json file
    Output: concatenated review text & date columns for a particular business id
    '''
    subset = reviews.loc[reviews['business_id'] == b_id]
    date = subset.loc[:, 'date']
    text = subset.loc[:, 'text']
    return pd.concat([date, text], axis=1, join='inner')

#trying with single business id / not tested
def k_index_emb_single(b_id, reviews):
    '''
    input:
    output: weight vectors for each topic, for every review from a particular business, concatenated
    '''
    subset = examine_reviews(b_id, reviews)
    s = examine_reviews(b_id, reviews)
    text_only = s.loc[:, 'text']
    for t in text_only:
        print(get_avg_k_index_for_doc(t, vec, tm))

#k_index_emb_single(,reviews)

def examine_reviews2(cat, business, reviews):
    '''
    concatenate a category's review text with the corresponding dates for time series analysis
    Input: specific category, review json file
    Output: concatenated review text & date columns for a particular category (not business specific) 
    '''
    
    id_list = business_id_retrieval(cat, business)
    return reviews.loc[reviews['business_id'].isin(id_list)]

s = examine_reviews('HRFJlSAP_EBU_MpPPmpUDQ', reviews)
it = s.loc[:, 'text']
for i in it:
    print(get_avg_k_index_for_doc(i, vec, tm))
# still testing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-aaba917bb263> in <module>()
#      43 it = s.loc[:, 'text']
#      44 for i in it:
# ---> 45     print(get_avg_k_index_for_doc(i, vec, tm))
#
# <ipython-input-60-94ddd9ae4ab2> in get_avg_k_index_for_doc(doc, vec, tm)
#      36         return []
#      37     else:
# ---> 38         tm_mat = tm.components
#      39         k_index = np.array([0.]*tm_mat.shape[0])
#      40         for s in sent_text:
#
# AttributeError: 'NMF' object has no attribute 'components'

# %%
#find trend
