# %%
import pickle
with open("review_user_top10_5star_list.txt", "rb") as f:
    review_user_top10_5star_list = pickle.load(f)

# %%
import pickle
with open("review_user_top10_1star_list.txt", "rb") as f:
    review_user_top10_1star_list = pickle.load(f)

# %%
import pickle
with open("review_user_top10_list.txt", "rb") as f:
    review_user_top10_list = pickle.load(f)

# %%
import nltk
 
def format_sentence(sent):
    return({word: True for word in nltk.word_tokenize(sent)})
 
print(format_sentence("The cat is very cute"))
# Out:
# {'The': True, 'cat': True, 'is': True, 'very': True, 'cute': True}

# %%
neg = []

for i in review_user_top10_1star_list: 
    neg.append([format_sentence(i), 'neg'])

# %%
neg[:2]
# Out:
# [[{'(': True,
#    ')': True,
#    ',': True,
#    '.': True,
#    ':': True,
#    'At': True,
#    'Bonus': True,
#    'Ca': True,
#    'Clean': True,
#    'Convenient': True,
#    'During': True,
#    'English': True,
#    'Fast': True,
#    'French': True,
#    'I': True,
#    'Laval': True,
#    'Luckily': True,
#    'Once': True,
#    'Service': True,
#    'They': True,
#    'a': True,
#    'able': True,
#    'all': True,
#    'asked': True,
#    'beat': True,
#    'bus': True,
#    'buses': True,
#    'but': True,
#    'buy': True,
#    'by': True,
#    'ca': True,
#    'call': True,
#    'cities': True,
#    'clean': True,
#    'come': True,
#    'could': True,
#    'directed': True,
#    'directions': True,
#    'drive': True,
#    'expensive': True,
#    'extends': True,
#    'for': True,
#    'having': True,
#    'he': True,
#    'hours': True,
#    'how': True,
#    'in': True,
#    'janitor': True,
#    'kept': True,
#    'kiosk': True,
#    'least': True,
# ...

# %%
pos = []

for i in review_user_top10_5star_list: 
    pos.append([format_sentence(i), 'pos'])

# %%
training = pos[:int((.8)*len(pos))] + neg[:int((.8)*len(neg))]

# %%
from nltk.classify import NaiveBayesClassifier
 
classifier = NaiveBayesClassifier.train(training)

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#               Lighthouse = True              pos : neg    =      4.3 : 1.0
#                    Films = True              pos : neg    =      4.3 : 1.0
#                genommene = True              pos : neg    =      4.3 : 1.0
#               betrachtet = True              pos : neg    =      4.3 : 1.0
#              necessities = True              pos : neg    =      4.3 : 1.0
#                  trinken = True              pos : neg    =      4.3 : 1.0
#                     Make = True              pos : neg    =      4.3 : 1.0
#                     seit = True              pos : neg    =      4.3 : 1.0
#              übernachtet = True              pos : neg    =      4.3 : 1.0
# //www.cnn.com/2008/TRAVEL/09/01/star.trek.voyage.ending.ap/index.html = True              pos : neg    =      4.3 : 1.0

# %%
res = []
for i in review_user_top10_list:
    res.append([i, classifier.classify(format_sentence(i))])
    print(classifier.classify(format_sentence(i)))
# Out:
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# pos
# pos
# pos
# pos
# neg
# pos
# pos
# neg
# neg
# pos
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# pos
# pos
# pos
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# pos
# pos
# pos
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# neg
# pos
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# pos
# neg
# pos
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# neg
# neg
# pos
# neg
# pos
# neg
# pos
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# ...

# %%
res[:2]
# Out:
# [["Convenient subway system. Service now extends all the way to Laval, which you can't beat.\n\nFast. During normal hours, trains come by quite often, unlike other cities I could name.\n\nClean. Once I asked a janitor (in English) how to buy a metro ticket, whereupon he directed me (in French) to a kiosk where I could buy bus tickets. At least he kept the station clean. Luckily I was able to call my lifeline for directions on how to properly buy tickets. Bonus: They weren't expensive.\n\nCan't speak for the buses, but I love not having to drive.",
#   'neg'],
#  ["The drive-thru waitresses Cindy E. and Rosa have very good customer service. They are very good at taking your order and getting it right the first time, all the time. The food is always hot with no errors. This Panda Express is one of the better I've experienced. I'd recommend anyone passing through and wanting a good experience to visit this Panda Express location.",
#   'pos']]

# %%
# define a method to classify all the restaurants to pos or neg
from nltk.classify import NaiveBayesClassifier
def classifier_pn(p, n, t):
    pos = []

    for i in p: 
        pos.append([format_sentence(i), 'pos'])
    
    neg = []
    for i in n: 
        neg.append([format_sentence(i), 'neg'])
    
    training = pos[:int((.8)*len(pos))] + neg[:int((.8)*len(neg))]
    classifier = NaiveBayesClassifier.train(training)
    
    res = []
    for i in t:
        res.append([i, classifier.classify(format_sentence(i))])
        print(classifier.classify(format_sentence(i)))
    return res

# %%
import pickle
with open("res_1star_text_list.txt", "rb") as f:
    res_1star_text_list = pickle.load(f)

with open("res_5star_text_list.txt", "rb") as f:
    res_5star_text_list = pickle.load(f)

with open("res_text_list.txt", "rb") as f:
    res_text_list = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c95cff3371e7> in <module>()
#       7
#       8 with open("res_text_list.txt", "rb") as f:
# ----> 9     res_text_list = pickle.load(f)
#
# KeyboardInterrupt:

# %%
res = classifier_pn(res_5star_text_list[:5000], res_1star_text_list[:5000], res_text_list[:5000])
# Out:
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# neg
# pos
# neg
# pos
# neg
# pos
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# neg
# neg
# pos
# neg
# pos
# neg
# neg
# pos
# pos
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# neg
# neg
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# pos
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# neg
# neg
# pos
# pos
# neg
# pos
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# pos
# neg
# pos
# pos
# neg
# pos
# pos
# neg
# neg
# neg
# pos
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# neg
# pos
# pos
# pos
# neg
# neg
# pos
# pos
# pos
# neg
# pos
# neg
# pos
# pos
# neg
# neg
# pos
# neg
# neg
# pos
# neg
# ...

# %%
res[:10]
# Out:
# [['This place is horrible, we were so excited to try it since I got a gift card for my birthday. We went in an ordered are whole meal and they did not except are gift card, because their system was down. Unacceptable, this would have been so helpful if we would have known this prior!!',
#   'neg'],
#  ['For being fairly "fast" food.. Pei Wei (pronounced pay way I confirmed haha) is pretty darn good. we got a few things to share. I had the Asian chicken salad and was impressed! There was a decent amount of chicken. Some more veggies would be nice, but overall pretty good. The steak teriyaki was great as well as the fried rice. Over all good was good! Nice, clean, and reasonable.',
#   'neg'],
# ...
