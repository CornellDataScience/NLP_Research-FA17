# %% [markdown]
# # Topical Authority Finding

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import operator
import os
print(os.getcwd())
print(os.listdir('/Users/Brandon/Yelp Dataset/dataset'))
import json
import glob
from datetime import datetime
from pandas import HDFStore
# Out:
# /Users/Brandon/Yelp Dataset/Yelp-FA17/local-elites/brandon
# ['.DS_Store', 'business.json', 'businessReviews.json', 'checkin.json', 'photos.json', 'review.json', 'review5000.json', 'tip.json', 'user.json', 'user5000.json']

# %%
def load_json_to_df(datapass):
    '''
    Load the json file and parse the file to pandas dataframe format
    
    Input:
        datapass(str) : directory to the json file
    Output:
        df(dataframe) : pandas dataframe object
    '''
    
    data = [] 
    with open(datapass) as data_file: 
        for f in data_file:
            data.append(json.loads(f))
    df = pd.DataFrame(data)
    return df

# %%
# %%time
import_file = "/Users/Brandon/Yelp Dataset/dataset/review.json"
#json_pattern = os.path.join(import_file,'review[0-9].json')
#file_list = glob.glob(json_pattern)

review = load_json_to_df(import_file)
# Out:
# CPU times: user 1min 2s, sys: 22.2 s, total: 1min 24s
# Wall time: 1min 33s

# %%
import_file = '/Users/Brandon/Yelp Dataset/dataset/business.json'
business = pd.read_json(import_file, lines=True)

# %%
# %%time
import_file = '/Users/Brandon/Yelp Dataset/dataset/user.json'
user = pd.read_json(import_file, lines=True)
# Out:
# CPU times: user 59.7 s, sys: 49.1 s, total: 1min 48s
# Wall time: 2min 19s

# %%
#list(user)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12ce08bf5a17> in <module>()
#       1 #list(user)
# ----> 2 flatten(business)
#
# NameError: name 'flatten' is not defined

# %% [markdown]
# Find which businesses are classified as a specific category. Here we do an example just looking at restaurants.

# %%
#user[user['review_count']>5000]
list(business)
def categoryFind(x,cat):
    return cat in x;
restaurantIndex = business['categories'].apply(categoryFind,cat='Restaurants')
restaurants = business[restaurantIndex]
len(restaurants)
# Out:
# 51613

# %% [markdown]
# We have 51613 businesses, let's try to look at just the first 500 for now.

# %% [markdown]
# Let's take a look at reviews

# %%
#list(review)
list(business)
# Out:
# ['address',
#  'attributes',
#  'business_id',
#  'categories',
#  'city',
#  'hours',
#  'is_open',
#  'latitude',
#  'longitude',
#  'name',
#  'neighborhood',
#  'postal_code',
#  'review_count',
#  'stars',
#  'state']

# %% [markdown]
# Merge on all Businesses

# %%
# %%time
businessReviews = pd.merge(review, business,on='business_id',right_index=True,sort=False)
# Out:
# CPU times: user 10.5 s, sys: 14.6 s, total: 25 s
# Wall time: 41.6 s

# %%
businessReviews = businessReviews[['business_id', 'cool', 'funny', 'review_id', 'stars_x', 'text', 'useful', 'user_id', 'categories', 'review_count', 'stars_y']]

# %%
businessReviews
# Out:
#                     business_id  cool  funny               review_id  stars_x  \
# 0        uYHaNptLzDLoV_JZ_MuzUA     0      0  VfBHSwC5Vz_pbFluy07i9Q        5
# 1        uYHaNptLzDLoV_JZ_MuzUA     0      0  3zRpneRKDsOPq92tq7ybAA        3
# 2        uYHaNptLzDLoV_JZ_MuzUA     0      0  ne5WhI1jUFOcRn-b-gAzHA        3
# 3        uYHaNptLzDLoV_JZ_MuzUA     0      0  llmdwOgDReucVoWEry61Lw        4
# 4        uYHaNptLzDLoV_JZ_MuzUA     0      0  DuffS87NaSMDmIfluvT83g        5
# 5        uYHaNptLzDLoV_JZ_MuzUA     0      0  GvLmUkjUrOyFH8KFnmT1uw        5
# 6        uYHaNptLzDLoV_JZ_MuzUA     0      0  lGEl24NGj2HVBJrodeXcjg        4
# 7        uYHaNptLzDLoV_JZ_MuzUA     0      0  cUgvEy5wj7zYE68v1BzzVg        4
# 8        uYHaNptLzDLoV_JZ_MuzUA     2      0  FSB_BnvysBgH3JYrbFNcgw        4
# 9        uYHaNptLzDLoV_JZ_MuzUA     0      0  dhl3ZW9aAEX_T7_um5tfaQ        4
# 10       uYHaNptLzDLoV_JZ_MuzUA     1      1  JQJvnM3p-3eML05eKcTgiw        4
# ...

# %% [markdown]
# Merge on just a category

# %%
#%%time
#businessReviews = pd.merge(review, restaurants,on='business_id',right_index=True,sort=False)
# Out:
# CPU times: user 6.4 s, sys: 1.16 s, total: 7.56 s
# Wall time: 8.03 s

# %%
#hdf =HDFStore('/Users/Brandon/Yelp Dataset/dataset/businessReviews.h5')
#hdf.put('businessReviews', businessReviews, format='table', data_columns=True)
#with open('/Users/Brandon/Yelp Dataset/dataset/businessReviews.json', 'w') as f:
    #json.dump(businessReviews.to_json(orient='records', lines=True), f)

# %%
# %%time
bus_rev_users = pd.merge(businessReviews, user,on='user_id',right_index=True,sort=False)
# Out:
# CPU times: user 35.6 s, sys: 11.7 s, total: 47.3 s
# Wall time: 55.2 s

# %%
bus_rev_users = bus_rev_users[['business_id', 'cool_x', 'funny_x', 'review_id', 'stars_x', 'text', 'useful_x', 'user_id', 'categories', 'stars_y', 'average_stars', 'cool_y', 'elite', 'fans', 'friends', 'name', 'review_count_y', 'yelping_since']]

# %%
#with open('/Users/Brandon/Yelp Dataset/dataset/userReviews.json', 'w') as f:
    #json.dump(bus_rev_users.to_json(orient='records', lines=True), f)

# %%
#businessReviews
print(len(businessReviews))
print(len(bus_rev_users))
print(list(businessReviews))
print(list(bus_rev_users))
bus_rev_users.head(1000)
# Out:
# 4736897
# 4736897
# ['business_id', 'cool', 'funny', 'review_id', 'stars_x', 'text', 'useful', 'user_id', 'categories', 'review_count', 'stars_y']
# ['business_id', 'cool_x', 'funny_x', 'review_id', 'stars_x', 'text', 'useful_x', 'user_id', 'categories', 'stars_y', 'average_stars', 'cool_y', 'elite', 'fans', 'friends', 'name', 'review_count_y', 'yelping_since']
#                     business_id  cool_x  funny_x               review_id  \
# 0        uYHaNptLzDLoV_JZ_MuzUA       0        0  VfBHSwC5Vz_pbFluy07i9Q
# 66617    Nvi9RLcOdrJvSwcw-ziZQQ       0        0  gieaGL6UEtNGMJRpOPUHjg
# 1        uYHaNptLzDLoV_JZ_MuzUA       0        0  3zRpneRKDsOPq92tq7ybAA
# 277415   D2smJ2r0RrVoe0aGlT-2wA       0        0  BVwTKOMnEevDQI8n_CHjGg
# 988950   6Kl2SQp-zGo-nsdImLykxw       0        0  X3dAS9SjWLi25zexhZtOQA
# 1621720  WbddSfX26mRGXpyuy2ClYQ       0        0  mpajk91608DKrZdvHLt7KA
# 1935212  sQS0mRR_N-K3lzV8v3DFcw       0        0  4xts4YYUJNAE40rocQc_jA
# ...

# %%
# %%time
businessUsers = businessReviews[['user_id','business_id']]
# Out:
# CPU times: user 2.01 s, sys: 825 ms, total: 2.84 s
# Wall time: 3.15 s

# %%
# %%time
#busRevAgg = businessReviews.groupby('user_id').agg(' '.join)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
#busRevAgg.loc['kzyLOqiJvyw_FWFTw2rjiQ']

# %%
def numCategoryReviews(businessReviews):
    return businessReviews[['business_id','user_id']].groupby('user_id',as_index=False).count()

def average_star_category_rating(businessReviews):
    return businessReviews[['user_id','stars_x']].groupby('user_id',as_index=False).mean()

def std_star_category_rating(businessReviews):
    busRev = businessReviews[['user_id','stars_x']].groupby('user_id',as_index=False).agg(np.var)
    busRev['stars_x'] = busRev['stars_x'].pow(1./2)
    return busRev

def funny_useful_cool(businessReviews):
    return businessReviews[['user_id','funny','useful','cool']].groupby('user_id',as_index=False).sum()

def months_yelping(businessReviews):
    user_dates = businessReviews[['user_id','yelping_since']].drop_duplicates()
    curr_date = datetime(2017,10,17)
    uyelp_dates = [datetime.strptime(i, "%Y-%m-%d") for i in user_dates['yelping_since']]
    months_yelping = [(curr_date.year - i.year) * 12 + curr_date.month - i.month for i in uyelp_dates]
    user_dates['yelping_since'] = months_yelping
    return user_dates

def get_elite_users(df):
    temp = []
    for i in df['elite'].index.values:
        if df['elite'][i]:
            temp.append(i)
    return df.loc[temp][['user_id','elite']]

def feature1(df, df1):
    catRev = numCategoryReviews(df)
    catRev.columns = ['user_id','Num Category Reviews']
    averageCat = average_star_category_rating(df)
    averageCat.columns = ['user_id','Average Rating in Category']
    stdCat = std_star_category_rating(df)
    stdCat.columns = ['user_id','Std Dev of Ratings in Category']
    fuc = funny_useful_cool(df)
    monthsYelp = months_yelping(df1)
    monthsYelp.columns = ['user_id', 'Months Yelping']
    is_elite = get_elite_users(df1)
    features = catRev.merge(averageCat,on='user_id').merge(stdCat,on='user_id').merge(fuc,on='user_id').merge(monthsYelp,on='user_id').merge(is_elite,on='user_id')
    return features.fillna(0)

# %%
num_category_reviews = numCategoryReviews(businessReviews)
avg_star_rat = average_star_category_rating(businessReviews)
std_star_rat = std_star_category_rating(businessReviews)

# %%
fuc = funny_useful_cool(businessReviews)
months_yelper = months_yelping(bus_rev_users)

# %%
#businessReviews[['user_id','stars_x']].sort_values('user_id')

# %%
usersInCategory = businessReviews['user_id']
#usersInCategory

# %%
#bus_rev_users['elite'].loc[bus_rev_users.any()]
#index = bus_rev_users['elite'].index[bus_rev_users['elite'].apply(bus_rev_users.isempty)]
#def get_elite_users(df):
#    temp = []
#    for i in df['elite'].index.values:
#        if df['elite'][i]:
#            temp.append(i)
#    return temp, df.loc[temp]

# %%
elite_ind, elite_users = get_elite_users(bus_rev_users)
len(bus_rev_users.loc[elite_ind]['elite'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [user_id] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-3fb9e6db4db3> in <module>()
#       1 elite_ind, elite_users = get_elite_users(bus_rev_users)
# ...

# %%
feature_set_1 = feature1(businessReviews, bus_rev_users)

# %%
#feature_set_1.drop(feature_set_1.index[elite_ind],axis=0)
feature_set_1
# Out:
#                        user_id  Num Category Reviews  \
# 0       ---1lKK3aKOuomHnwAkAow                    53
# 1       ---PLwSf5gKdIoVnyRHgBA                     1
# 2       ---cu1hq55BP9DWVXXKHZg                     2
# 3       ---udAKDsn0yQXmzbWQNSw                     1
# 4       --0RtXvcOIE4XbErYca6Rw                     1
# 5       --0sXNBv6IizZXuV-nl0Aw                     1
# 6       --1av6NdbEbMiuBr7Aup9A                     1
# 7       --1mPJZdSY9KluaBYAGboQ                     1
# 8       --26jc8nCJBy4-7r3ZtmiQ                     1
# 9       --2HUmLkcNHZp0xw6AMBPg                    22
# 10      --2bpE5vyR-2hAP7sZZ4lA                     1
# 11      --2vR0DIsmQ6WfcSzKWigw                     5
# 12      --3WaS23LcIXtxyFULJHTA                    10
# 13      --3l8wysfp49Z2TLnyT0vg                     1
# 14      --3oMd6gjXpAzhjLBrsVCQ                     2
# 15      --41c9Tl0C9OGewIR7Qyzg                     3
# 16      --44NNdtngXMzsxyN7ju6Q                     1
# ...

# %%
elite_features = feature1(businessReviews.loc[elite_ind], elite_users)
elite_features
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [user_id] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5e54411d11cc> in <module>()
# ----> 1 elite_features = feature1(businessReviews.loc[elite_ind], elite_users)
# ...

# %% [markdown]
# We have 63861 Elite Users, we will use these to get the truth on the category. - Experts in Restaurants

# %% [markdown]
# TRAINING RANDOM FOREST ON THE MODEL

# %%
expert = 1
not_expert = 0
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
X, y = feature_set_1.drop('user_id',axis=1), [1]*len(feature_set_1)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X,y)

# %%
businessReviews.loc[elite_ind][1:2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [user_id] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-6efe411685bb> in <module>()
# ----> 1 businessReviews.loc[elite_ind][1:2]
#
# ...

# %%
bus_rev_users.loc[elite_ind][1:2]

# %%
elite_users
# Out:
# 'elite'

# %%
x=get_elite_users(bus_rev_users)[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-012c9af007ca> in <module>()
# ----> 1 x=get_elite_users(bus_rev_users)[1]
#
# ...

# %%
x['elite']

# %%
feature_set_1 = feature1(businessReviews, bus_rev_users)

# %%
bus_rev_users
