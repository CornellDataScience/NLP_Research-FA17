# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
def load_json_to_df(datapass):
    '''
    Load the json file and parse the file to pandas dataframe format
    
    Input:
        datapass(str) : directory to the json file
    Output:
        df(dataframe) : pandas dataframe object
    '''
    
    data = [] 
    with open(datapass) as data_file: 
        for f in data_file:
            data.append(json.loads(f))
    df = pd.DataFrame(data)
    return df

# %%
checkin = load_json_to_df("checkin.json")

# %%
check = checkin["time"]

# %%
def numofeachday(rest):
    d = {}
    for i in rest.keys():
        d[i] = sum(rest[i].values())
    return d

# %%
l = []
for i in range(100000):
    l.append(numofeachday(check[i]))
dic = {'Sunday': 0,'Monday': 0, 'Tuesday': 0,'Wednesday': 0,'Thursday': 0,  'Friday': 0, 'Saturday': 0}
for i in l:
    for day in i.keys():
        dic[day] += i[day]
dic
# Out:
# {'Friday': 1925975,
#  'Monday': 1618938,
#  'Saturday': 2636624,
#  'Sunday': 2415908,
#  'Thursday': 1661307,
#  'Tuesday': 1565940,
#  'Wednesday': 1616063}

# %%
l = []
for i in dic.values():
    print (i)
    l.append(i)
    
plt.plot(range(7),l)
plt.show()
# Out:
# 2415908
# 1618938
# 1565940
# 1616063
# 1661307
# 1925975
# 2636624

# %%
biz = load_json_to_df("business.json")

# %%
biz.head(10)
# Out:
#                                address  \
# 0                      691 Richmond Rd
# 1                       2824 Milton Rd
# 2                  337 Danforth Avenue
# 3  7702 E Doubletree Ranch Rd, Ste 300
# 4                       4719 N 20Th St
# 5                  2017 E Camelback Rd
# 6              4425 N 24th St, Ste 125
# 7                       5770 Butler St
# 8                   3220 Washington Rd
# 9            1425 S Higley Rd, Ste 103
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': 2, 'BusinessParking...  YDf95gJZaq05wvo7hTQbbQ
# 1  {'GoodForMeal': {'dessert': False, 'latenight'...  mLwM-h2YhXl2NCgdS84_Bw
# 2  {'BusinessParking': {'garage': False, 'street'...  v2WhjAB3PIBA8J8VxG3wEg
# 3                                                 {}  CVtCbSB1zUcUWg-9TNGTuQ
# 4  {'RestaurantsTableService': False, 'GoodForMea...  duHFBe87uNSXImQmvBh87Q
# 5  {'BusinessAcceptsCreditCards': True, 'Restaura...  uUEMrhJiL1a1pCA_I1SU7Q
# 6  {'AcceptsInsurance': True, 'ByAppointmentOnly'...  2eJEUJIP54tex7T9YOcLSw
# 7               {'BusinessAcceptsCreditCards': True}  fEylCY3UEH8YJ0Xa7lu6lA
# 8  {'DogsAllowed': True, 'BusinessParking': {'gar...  kFtuYklkAIlmYw8RZAieGw
# 9  {'AcceptsInsurance': True, 'ByAppointmentOnly'...  NqiQdFa93wzUJGo29NbTPQ
#
#                                           categories              city  \
# 0                       [Shopping, Shopping Centers]  Richmond Heights
# 1  [Food, Soul Food, Convenience Stores, Restaura...         Charlotte
# 2                               [Food, Coffee & Tea]           Toronto
# 3               [Professional Services, Matchmakers]        Scottsdale
# 4                          [Sandwiches, Restaurants]           Phoenix
# 5                          [Shopping, Tobacco Shops]           Phoenix
# 6                  [Chiropractors, Health & Medical]           Phoenix
# 7  [Automotive, Oil Change Stations, Car Wash, Au...        Pittsburgh
# 8  [Jewelry Repair, Gold Buyers, Local Services, ...          McMurray
# 9                   [Health & Medical, Optometrists]           Gilbert
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '10:00-21:00', 'Tuesday': '10:00-21...        1  41.541716
# 1  {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...        0  35.236870
# 2  {'Monday': '10:00-19:00', 'Tuesday': '10:00-19...        0  43.677126
# 3  {'Friday': '9:00-17:00', 'Tuesday': '9:00-17:0...        1  33.565082
# 4                                                 {}        0  33.505928
# 5  {'Monday': '10:00-20:00', 'Tuesday': '10:00-20...        0  33.508068
# 6  {'Friday': '9:00-12:00', 'Tuesday': '14:00-19:...        1  33.502848
# 7  {'Monday': '8:00-17:00', 'Tuesday': '8:00-17:0...        1  40.485939
# 8  {'Monday': '10:00-18:00', 'Tuesday': '10:00-18...        1  40.290498
# 9  {'Friday': '7:30-11:00', 'Tuesday': '7:30-17:0...        1  33.324539
#
#     longitude                                name   neighborhood postal_code  \
# 0  -81.493116                Richmond Town Square                      44143
# 1  -80.741976  South Florida Style Chicken & Ribs       Eastland       28215
# 2  -79.353285                    The Tea Emporium      Riverdale     M4K 1N7
# 3 -111.916400                            TRUmatch                      85258
# 4 -112.038847                             Blimpie                      85016
# 5 -112.037552                     Baxter's Cigars                      85016
# 6 -112.012696            Back-Health Chiropractic                      85016
# 7  -79.943727                       Auto Bathouse  Lawrenceville       15201
# 8  -80.110021                 JAB Jewelry Designs                      15317
# 9 -111.720449          Neighborhood Vision Center                      85296
#
#    review_count  stars state
# 0            17    2.0    OH
# 1             4    4.5    NC
# 2             7    4.5    ON
# 3             3    3.0    AZ
# 4            10    4.5    AZ
# 5            35    5.0    AZ
# 6            19    5.0    AZ
# 7            16    2.5    PA
# 8             7    5.0    PA
# 9             8    5.0    AZ

# %%
biz.groupby('state').sum().sort_values(by = 'stars', ascending = False)
# Out:
#        is_open      latitude     longitude  review_count     stars
# state
# AZ       40193  1.586757e+06 -5.305489e+06       1459409  176608.0
# NV       25648  1.104194e+06 -3.520700e+06       1650578  113509.0
# ON       21755  1.158976e+06 -2.106336e+06        570082   91375.0
# NC        9696  3.979954e+05 -9.133040e+05        272977   40474.5
# OH        9490  4.527218e+05 -8.924869e+05        219072   39064.5
